# %% [markdown]
# ______
#
# <img src="./imgs/DRRlogo.jpg" width="350" />
#
# # Land Cover Classification for use in the CAPRA Model
#
# ## Image Classification
# _____

# %% [markdown]
# ### Learning Objectives
#
# In this lesson you will learn concepts of supervised classification. You will explore processes of training data collection, classifier selection, classifier training, image classification and accuracy assessment.
#
# The purpose of this tutorial is to derive a land cover map from satellite imagery using a classification method called recursive partitioning. The procedure for the classification process is outlined in Figure 2.
# The tutorial will use the open source software Google Earth Engine (GEE) and its Python API. We will cover common tasks for data loading, image visualization and processing. The main steps of the classification process we developed for this tutorial with relevant software indicated in () are:
#
# Image classification means mapping the values captured by remote sensors that are encoded as image digital levels to specific land cover types. <br>
# Classifying remotely sensed data into a thematic map is a relevant task beacuse the resulting information is the basis for many environmental and socioeconomic applications. In this example, a crop map type is produced by applying a [*supervised*](https://en.wikipedia.org/wiki/Supervised_learning) [*Random Forest*](https://en.wikipedia.org/wiki/Random_forest) algorithm.

# %% [markdown]
# <img src="./imgs/JensenClfProcess_.PNG">
#
# **Figure 1. Procedure for the acquisition and classification process of remotely sensed imagery (adapted from Jensen 2005)**

# %% [markdown]
# ### Supervised Classification

# %% [markdown]
# A supervised classification method consists of training a classifier (algorithm) using (ground) truth data to classify  subsequently unseen data. <br>
# The process flow in a supervised classification includes basically, the following steps:
# * Collect the ground data. This data is used to train the classifier and validate its results.
# * Train the classifier.
# * Apply the classifier to produce a classified image.
# * Assess the classification accuracy.

# %% [markdown]
# ### Classification Scheme Definition

# %% [markdown]
# The classes and the detail of a classification scheme of a land cover map are determined by its intended use.  A classification scheme can have multiple levels of detail.  It is good practice to design a classification scheme with mutually exclusive and exhaustive classes of either land cover OR land use.  For different levels or scales the class details need to be determined in a way that they can be easily aggregated such as in a hierarchical structure.
#
# The classification scheme used in the runoff factor map delineation in the CAPRA flood model consists of a mixture of detailed land cover and land use classes as described in Table 1.  This is not an optimal scenario as overlap of classes can lead to non-exclusiveness of classes (e.g., impermeable surface and paved roads).  It is not consistent in the level of the hierarchical structure either.  The two level one forest land cover classes in the classification scheme are “natural forests” differentiated from “forests” which at the second level are further divided into  seeded or cultivated.  Further “cropped furrows”,” cereals”, “leguminous” and their subclasses can be grouped under agricultural or cropland at the first level. Roads, rangeland and rest (uncultivated) are pure land use classes, with class “rangeland” overlapping with class “pasture”.
#
# In general it is a lot more difficult to derive land use from a remotely sensed image than it is to detect land cover, as land cover describes the surface material and therefore has a direct linkage to the spectral reflectance behavior of the material (e.g. land cover grassland vs. land use classes pasture, football field, city park).  Land use classification of detailed agricultural classes as suggested by the CAPRA classification scheme requires a very good knowledge and expertise of a region’s agricultural practices.
#
# An important component of a land-cover classification procedure is the proper choice and delineation of training sites, used to train the computer in pattern recognition.  It is crucial to develop a database of reference points with reliable ground cover or use information at the spatial scale and thematic detailed at which the mapping procedure will be performed.  Preferably such reference points are acquired in the field (in situ) or from high resolution aerial photography.  For each of the different land cover types of interest a set of representative samples would be collected using a GPS (or digitizing technique).
#
# In our case we do not have a database of ground reference points or aerial photography, and we do not have an intimate knowledge of agricultural practices of the region, therefore we will refer to the U.S. Geological Survey Land Use/Land Cover Classification System for use with Remote Sensor Data (Tbl. 2).

# %% [markdown]
# **Table 2. Land use and land cover classification system for use with remote sensor data (Anderson et al., 1976)**
#
# <img src="./imgs/LCclassTable_.PNG">

# %% [markdown]
# For this tutorial we will use classes based on level one of the USGS classification system.  The classes of interest for our mapping application are: Water, Forest Land, Rangeland, Agricultural Land, Barren Land, and Urban or Built-up Land.
# Since the classification scheme is a mix of land cover and land use we will rename classes with land use character to their corresponding land cover.  We also want to avoid spaces in the class names since we are going to use the names in code and spaces can be problematic.  The class names we are going to use instead are:
#
# (1)	water
# (2)	forestLand
# (3)	cropLand
# (4)	buildUpLand

# %% [markdown]
# #### Question:
# #### (1) Which of the level one classes of the U.S. Geological Survey Land Use/Land Cover Classification System for use with remote                  sensor Data do you expect to be present in your ROI (google it).

# %% [markdown]
# ### Remote Sensing Process
#
# One of the more common procedures to generate thematic land cover maps of a region is by applying pattern-recognition algorithms to satellite imagery in a digital image processing environment.  The use of remote sensing classification methods involve three general steps, (1) the selection and pre-processing of imagery adequate for the mapping of land cover classes of interest at their appropriate scales, (2) extraction and evaluation of spectral signatures and their statistical separability for all land cover classes of interest and development of a classification method and (3) evaluation and documentation of the mapping process and the final map product.
#
# (1)	Discrimination, and mapping of various land use/land cover classes depends on the spatial resolution (pixel size); the spectral resolution (number of bands or channels and their bandwidth); the radiometric resolution (range of discrete brightness values); and the temporal resolution (return time of the sensor) in relation to the classification scheme and minimum mapping unit or appropriate scale (Teillet et al., 1997 ,Rao et al., 2007).  Since the limitations of a mapping project are often constrained by its budget, the most economic approach to consider is to use data free of charge processed with open source image processing software, which is the a solution demonstrated in this tutorial.
#
# A large Landsat archive of 45 years of image acquisitions is available and open to the public. Landsat sensor specific information are accessible through the data portal of USGS (http://landsat.usgs.gov/Landsat_Search_and_Download.php).  For this exercise we are going to use Landsat 8 images. The Scan Line Corrector (SLC) in the Landsat 7 failed in in April of 2003 resulting in imagery with significant geometric error and considerable areas of no data value in each scene.  The Landsat 8 data source is adequate for the classes we identified in the classification scheme. Google Earth Engine (GEE) contains a variety of Landsat specific processing methods. Specifically, there are methods to compute at-sensor radiance, top-of-atmosphere reflectance, surface reflectance, cloud score and cloud-free composites.
#
# (2)	The extraction and evaluation of spectral signatures of all land cover classes of interest requires a training dataset.  In this exercise a set of training points for each class will be digitized on screen using the Google Earth application.  For the digitized sampling points spectral characteristics will then be extracted from the pre-processed imagery.  The variables we are interested in evaluating are reflectance values.  In addition we will consider derivative information, the Normalized Difference Vegetation Index (NDVI) and tasseled cap or Kauth-Thomas transformation which is based on the relationship of spectral characteristics to soil brightness, moisture content and vegetation cover.  The pre-processing and preparation of all data and the extraction of variable values for each sample of the training data set will be performed in Google Earth and GEE.
#
# The classification process is guided by the evaluation of the separability of classes for different combinations of reflectance bands and other derived variables based on the training set.  Separability analysis and feature selection are frequently based on descriptive class parameters such as the class specific mean vector and variance-covariance matrices.  For this tutorial instead of using parametric measures to evaluate class-separability, we will evaluate the effectiveness of a recursive partitioning algorithm, a non-parametric classification procedure (see pg. 38 in landCoverClassification_Theory.pdf).  Performance of different classifiers is assessed for all evaluated models based on accuracy measures derived from confusion matrices of the classified training dataset.  This initial evaluation of accuracies has a bias towards overestimating accuracies, and will only be used to select the model with the best fit.  The analysis will provide two important components for the final classification, a list of variables that are most suitable to differentiate the classes of interest, and the decision rules or classification tree (the model or classifier), that will be applied to all pixels of the entire area of interest, the Dominican Republic.  This part of the analysis will be performed in GEE Python API.
#
# (3)	The final step of the mapping project is the accuracy assessment of the final classification results (the final map).  For this purpose we will use a stratified random sampling design (see pg. 45 in landCoverClassification_Theory.pdf) applied to the sampling frame of all classified image elements (pixels).  For lack of ground reference data we will use Google Earth (or Google maps) as reference source to determine classification accuracy.

# %%
# Import required modules

import bqplot
import datetime
import dateutil.parser
import ee
import ipywidgets
import ipyleaflet
import IPython.display
import numpy as np
import pprint
import pandas as pd
import traitlets

# Configure the pretty printing output & initialize earthengine.
pp = pprint.PrettyPrinter(depth=4)
ee.Initialize()

# %%
import ee
from IPython.display import Image
ee.Initialize()
import pprint
import matplotlib as mp

# Configure the pretty printing output.
pp = pprint.PrettyPrinter(depth=4)

# %%
# Function to get sizes in Human readable format
suffixes = ['B', 'KB', 'MB', 'GB', 'TB', 'PB']
def humansize(nbytes):
    i = 0
    while nbytes >= 1024 and i < len(suffixes)-1:
        nbytes /= 1024.
        i += 1
    f = ('%.2f' % nbytes).rstrip('0').rstrip('.')
    return '%s %s' % (f, suffixes[i])

# %%
# Function to get tilelayer url from earthengine server
def GetTileLayerUrl(ee_image_object):
  map_id = ee.Image(ee_image_object).getMapId()
  tile_url_template = "https://earthengine.googleapis.com/map/{mapid}/{{z}}/{{x}}/{{y}}?token={token}"
  return tile_url_template.format(**map_id)

# %% [markdown]
# ## Masking clouds and cloud shadows
#
# Clouds and atmospheric conditions present a significant challenge when working with multispectral remote sensing data. Extreme cloud cover and shadows can make the data in those areas unusable if reflectance values are either washed out (too bright - as the clouds scatter all light back to the sensor) or are too dark (shadows which represent blocked or absorbed light).
#
# Many remote sensing data sets come with quality layers that you can use as a mask to remove “bad” pixels from your analysis. In the case of Landsat, the mask layers identify pixels that are likely representative of cloud cover, shadow and even water. Landsat 8 data comes with a processed cloud shadow/mask raster layer called pixel_qa.
#
#
# In the following section of code you will sort the Landsat 8 surface reflectance image collection,  in order to get the most recent, oldest, or optimal image. Then you will use first() to obtain the first least cloudy image.

# %%
# Sort collection from least to most cloudy
l8sr = ee.ImageCollection('LANDSAT/LC08/C01/T1_SR').sort('CLOUD_COVER')

# Get the first, least cloudy image from the collection
pixel_qa_image = ee.Image(
    l8sr.filterDate('2015-01-01', '2019-12-30')
        .filterBounds(ee.Geometry.Point(-70.0522, 18.7490))
        .first()
        .select('pixel_qa')
)
pp.pprint(pixel_qa_image.getInfo())
# Out:
# {'bands': [{'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 65535,
#                           'min': 0,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'pixel_qa'}],
#  'id': 'LANDSAT/LC08/C01/T1_SR/LC08_007047_20160116',
#  'properties': {'CLOUD_COVER': 4.49,
#                 'CLOUD_COVER_LAND': 7.32,
#                 'EARTH_SUN_DISTANCE': 0.983695,
#                 'ESPA_VERSION': '2_23_0_1a',
#                 'GEOMETRIC_RMSE_MODEL': 7.083,
#                 'GEOMETRIC_RMSE_MODEL_X': 4.812,
#                 'GEOMETRIC_RMSE_MODEL_Y': 5.198,
#                 'IMAGE_QUALITY_OLI': 9.0,
#                 'IMAGE_QUALITY_TIRS': 9.0,
#                 'LANDSAT_ID': 'LC08_L1TP_007047_20160116_20170405_01_T1',
#                 'LEVEL1_PRODUCTION_DATE': 1491376888000.0,
#                 'PIXEL_QA_VERSION': 'generate_pixel_qa_1.6.0',
#                 'SATELLITE': 'LANDSAT_8',
#                 'SENSING_TIME': '2016-01-16T15:02:40.0636270Z',
#                 'SOLAR_AZIMUTH_ANGLE': 145.575439,
#                 'SOLAR_ZENITH_ANGLE': 47.468399,
#                 'SR_APP_VERSION': 'LaSRC_1.3.0',
#                 'WRS_PATH': 7.0,
#                 'WRS_ROW': 47.0,
#                 'system:asset_size': 481562171,
#                 'system:footprint': {'coordinates': [[...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...]],
#                                      'type': 'LinearRing'},
#                 'system:index': 'LC08_007047_20160116',
#                 'system:time_start': 1452956560060.0},
#  'type': 'Image',
#  'version': 1522730651043244}

# %%
# the maximun pixel value is 65535 because the image has 16-bit per pixel 
url  = pixel_qa_image.getThumbUrl({'min':0, 'max':3000})
# you could copy and paste this url in a browser to see the image 
print(url)
# display image thumbnails.
Image(url=url)
# Out:
# https://earthengine.googleapis.com/api/thumb?thumbid=2fc330c1b208cf8a1ad3d67bab94696b&token=b21e9cbc68b42bdb5305eca71b4250cf
# <img src="https://earthengine.googleapis.com/api/thumb?thumbid=2fc330c1b208cf8a1ad3d67bab94696b&token=b21e9cbc68b42bdb5305eca71b4250cf"/>

# %%
vis_image = ee.Image(
    l8sr.filterDate('2015-01-01', '2019-12-30')
        .filterBounds(ee.Geometry.Point(-70.0522, 18.7490))
        .first()
        .select('B[2-5]')
)
pp.pprint(vis_image.getInfo())

Image(url=vis_image.getThumbUrl({'min': 0, 'max': 6000,'bands': 'B4,B3,B2', 'gamma': '0.95, 1.1, 1'}))
# Out:
# {'bands': [{'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767,
#                           'min': -32768,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B2'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767,
#                           'min': -32768,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B3'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767,
#                           'min': -32768,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B4'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767,
#                           'min': -32768,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B5'}],
#  'id': 'LANDSAT/LC08/C01/T1_SR/LC08_007047_20160116',
#  'properties': {'CLOUD_COVER': 4.49,
#                 'CLOUD_COVER_LAND': 7.32,
#                 'EARTH_SUN_DISTANCE': 0.983695,
#                 'ESPA_VERSION': '2_23_0_1a',
#                 'GEOMETRIC_RMSE_MODEL': 7.083,
#                 'GEOMETRIC_RMSE_MODEL_X': 4.812,
#                 'GEOMETRIC_RMSE_MODEL_Y': 5.198,
#                 'IMAGE_QUALITY_OLI': 9.0,
#                 'IMAGE_QUALITY_TIRS': 9.0,
#                 'LANDSAT_ID': 'LC08_L1TP_007047_20160116_20170405_01_T1',
#                 'LEVEL1_PRODUCTION_DATE': 1491376888000.0,
#                 'PIXEL_QA_VERSION': 'generate_pixel_qa_1.6.0',
#                 'SATELLITE': 'LANDSAT_8',
#                 'SENSING_TIME': '2016-01-16T15:02:40.0636270Z',
#                 'SOLAR_AZIMUTH_ANGLE': 145.575439,
#                 'SOLAR_ZENITH_ANGLE': 47.468399,
#                 'SR_APP_VERSION': 'LaSRC_1.3.0',
#                 'WRS_PATH': 7.0,
#                 'WRS_ROW': 47.0,
#                 'system:asset_size': 481562171,
#                 'system:footprint': {'coordinates': [[...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...]],
#                                      'type': 'LinearRing'},
#                 'system:index': 'LC08_007047_20160116',
#                 'system:time_start': 1452956560060.0},
#  'type': 'Image',
#  'version': 1522730651043244}
# <img src="https://earthengine.googleapis.com/api/thumb?thumbid=60b7be4243a3a340f3eda930c1c59f12&token=a08ab23d97aaff4382aa7f668ecb346e"/>

# %%
#Create a slider widget to add both Landsat 8 and PlanetScope 4B SR imagery
map1 = ipyleaflet.Map(
    center=(18.7490, -70.0522), zoom=12,
    layout={'height':'500px'},
)
# ps4bsr_tile_url=GetTileLayerUrl(ps4bsr.median().visualize(min=600, max=4000, bands=['b4', 'b3', 'b2']))
l8sr_tile_url = GetTileLayerUrl(l8sr.median().visualize(min=100, max=3500, gamma=1.5, bands= ['B5', 'B3', 'B2']))  #Landsat 8 SR
# left = ipyleaflet.TileLayer(url=ps4bsr_tile_url)
right=ipyleaflet.TileLayer(url=l8sr_tile_url)
control = ipyleaflet.SplitMapControl(right_layer=right)
map1.add_control(control)
map1
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %%
# Define function to mask clouds by using the pixel QA band to mask clouds in surface reflectance (SR) data.
def maskL8sr(image):
    # Bits 3 and 5 are cloud shadow and cloud, respectively.
    cloud_shadow_bit_mask = (1 << 3)
    clouds_bit_mask = (1 << 5)
    # Get the pixel QA band.
    qa = image.select('pixel_qa');
    # Both flags should be set to zero, indicating clear conditions.
    mask = qa.bitwiseAnd(cloud_shadow_bit_mask).eq(0) and (qa.bitwiseAnd(clouds_bit_mask).eq(0))
    # Return the masked image, scaled to reflectance, without the QA bands.
    return image.updateMask(mask).select("B[0-9]*").copyProperties(image, ["system:time_start"])#.divide(10000)

l8sr_mask = ee.ImageCollection('LANDSAT/LC08/C01/T1_SR').sort('CLOUD_COVER').map(maskL8sr)

mask_image = ee.Image(
    l8sr_mask.filterDate('2015-01-01', '2019-12-30')
             .filterBounds(ee.Geometry.Point(-70.0522, 18.7490))
             .first()
             .select('B[2-5]')
)

#mask_image = l8sr_mask.filterDate('2015-01-01', '2019-12-30').filterBounds(ee.Geometry.Point(-70.0522, 18.7490)).first()

pp.pprint(mask_image.getInfo())

Image(url=mask_image.getThumbUrl({'min': 0, 'max': 2000,'bands': 'B4,B3,B2', 'gamma': '0.95, 1.1, 1'}))
# Out:
# {'bands': [{'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767,
#                           'min': -32768,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B2'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767,
#                           'min': -32768,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B3'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767,
#                           'min': -32768,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B4'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767,
#                           'min': -32768,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B5'}],
#  'id': 'LANDSAT/LC08/C01/T1_SR/LC08_007047_20160116',
#  'properties': {'CLOUD_COVER': 4.49,
#                 'CLOUD_COVER_LAND': 7.32,
#                 'EARTH_SUN_DISTANCE': 0.983695,
#                 'ESPA_VERSION': '2_23_0_1a',
#                 'GEOMETRIC_RMSE_MODEL': 7.083,
#                 'GEOMETRIC_RMSE_MODEL_X': 4.812,
#                 'GEOMETRIC_RMSE_MODEL_Y': 5.198,
#                 'IMAGE_QUALITY_OLI': 9.0,
#                 'IMAGE_QUALITY_TIRS': 9.0,
#                 'LANDSAT_ID': 'LC08_L1TP_007047_20160116_20170405_01_T1',
#                 'LEVEL1_PRODUCTION_DATE': 1491376888000.0,
#                 'PIXEL_QA_VERSION': 'generate_pixel_qa_1.6.0',
#                 'SATELLITE': 'LANDSAT_8',
#                 'SENSING_TIME': '2016-01-16T15:02:40.0636270Z',
#                 'SOLAR_AZIMUTH_ANGLE': 145.575439,
#                 'SOLAR_ZENITH_ANGLE': 47.468399,
#                 'SR_APP_VERSION': 'LaSRC_1.3.0',
#                 'WRS_PATH': 7.0,
#                 'WRS_ROW': 47.0,
#                 'system:asset_size': 481562171,
#                 'system:footprint': {'coordinates': [[...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...]],
#                                      'type': 'LinearRing'},
#                 'system:index': 'LC08_007047_20160116',
#                 'system:time_start': 1452956560060.0},
#  'type': 'Image',
#  'version': 1522730651043244}
# <img src="https://earthengine.googleapis.com/api/thumb?thumbid=f72cef1c6ad1c591309077fdfd8deca7&token=bda49c9cb1b16bb298ebf0cc23adbdcf"/>

# %%
#region = area_of_interest.bounds().getInfo()['coordinates'][0]
task = ee.batch.Export.image.toDrive(
  image = mask_image,
  description = "mask_image",
  #assetId = 'users/ximenamesa/LC' + "DR",
  maxPixels = 12997211221,   
  #region = region,
  scale = 2)
task.start()
print("Task started")
# Out:
# Task started

# %% [markdown]
# ## ee.Algorithms.Landsat.simpleComposite()
#
# For creating simple cloud-free Landsat composites, Earth Engine provides the ee.Algorithms.Landsat.simpleComposite() method. This method selects a subset of scenes at each location, converts to TOA reflectance, applies the simple cloud score and takes the median of the least cloudy pixels. This example creates a simple composite using default parameters and compares it to a composite using custom parameters for the cloud score threshold and the percentile:

# %% [markdown]
# ## Stack L8 bands, NDVI, texture
#
# Classification result could be improved by adding more data such as vegetation indices and textural features.

# %%
# NDVI data
# compute the normalized vegetation index using Infrared and red bands
# NDVI = (NIR - red) / (NIR + red)

# Functions to derive vegetation indices and other raster operations
def NDVI(image):
    return image.normalizedDifference(['B5', 'B4'])

ndvi = NDVI(mask_image)

# Texture Data
# Define the kernel
kernel = ee.Kernel.square(1, 'pixels')  # filter mean of 3*3
# Compute mean as texture of the landsat 8 collection
mean = mask_image.reduceNeighborhood(
    ee.Reducer.mean(),
    kernel
)

pp.pprint(mean.getInfo())
# Out:
# {'bands': [{'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767.0,
#                           'min': -32768.0,
#                           'precision': 'double',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B2_mean'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767.0,
#                           'min': -32768.0,
#                           'precision': 'double',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B3_mean'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767.0,
#                           'min': -32768.0,
#                           'precision': 'double',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B4_mean'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767.0,
#                           'min': -32768.0,
#                           'precision': 'double',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B5_mean'}],
#  'properties': {'system:footprint': {'coordinates': [[...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...]],
#                                      'type': 'LinearRing'}},
#  'type': 'Image'}

# %%
spectral_indices_stack = ee.Image(mask_image).addBands(ndvi).addBands(mean)
pp.pprint(spectral_indices_stack.getInfo())
# Out:
# {'bands': [{'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767,
#                           'min': -32768,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B2'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767,
#                           'min': -32768,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B3'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767,
#                           'min': -32768,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B4'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767,
#                           'min': -32768,
#                           'precision': 'int',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B5'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 1.0,
#                           'min': -1.0,
#                           'precision': 'float',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'nd'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767.0,
#                           'min': -32768.0,
#                           'precision': 'double',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B2_mean'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767.0,
#                           'min': -32768.0,
#                           'precision': 'double',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B3_mean'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767.0,
#                           'min': -32768.0,
#                           'precision': 'double',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B4_mean'},
#            {'crs': 'EPSG:32619',
#             'crs_transform': [30.0, 0.0, 305985.0, 0.0, -30.0, 2193615.0],
#             'data_type': {'max': 32767.0,
#                           'min': -32768.0,
#                           'precision': 'double',
#                           'type': 'PixelType'},
#             'dimensions': [7621, 7771],
#             'id': 'B5_mean'}],
#  'id': 'LANDSAT/LC08/C01/T1_SR/LC08_007047_20160116',
#  'properties': {'CLOUD_COVER': 4.49,
#                 'CLOUD_COVER_LAND': 7.32,
#                 'EARTH_SUN_DISTANCE': 0.983695,
#                 'ESPA_VERSION': '2_23_0_1a',
#                 'GEOMETRIC_RMSE_MODEL': 7.083,
#                 'GEOMETRIC_RMSE_MODEL_X': 4.812,
#                 'GEOMETRIC_RMSE_MODEL_Y': 5.198,
#                 'IMAGE_QUALITY_OLI': 9.0,
#                 'IMAGE_QUALITY_TIRS': 9.0,
#                 'LANDSAT_ID': 'LC08_L1TP_007047_20160116_20170405_01_T1',
#                 'LEVEL1_PRODUCTION_DATE': 1491376888000.0,
#                 'PIXEL_QA_VERSION': 'generate_pixel_qa_1.6.0',
#                 'SATELLITE': 'LANDSAT_8',
#                 'SENSING_TIME': '2016-01-16T15:02:40.0636270Z',
#                 'SOLAR_AZIMUTH_ANGLE': 145.575439,
#                 'SOLAR_ZENITH_ANGLE': 47.468399,
#                 'SR_APP_VERSION': 'LaSRC_1.3.0',
#                 'WRS_PATH': 7.0,
#                 'WRS_ROW': 47.0,
#                 'system:asset_size': 481562171,
#                 'system:footprint': {'coordinates': [[...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...],
#                                                      [...]],
#                                      'type': 'LinearRing'},
#                 'system:index': 'LC08_007047_20160116',
#                 'system:time_start': 1452956560060.0},
#  'type': 'Image',
#  'version': 1522730651043244}

# %% [markdown]
# ## Training Points
#
# We're going to perform a supervised forest change classification using the random forests algorithm. To do so, we need to provide this algorithm with training data, i.e. we need to delineate areas of known fate to characterized the spectral signatures of the different classes. In particular, we're interested in the following 4 classes:
#
# 1. Water
# 2. Forest
# 3. urban
# 4. Agriculture
#
# ## Upload fusion table

# %%
def edit_kmz(kmz,output,image):
  zf = zipfile.ZipFile(kmz)
  temp = r'tempfolder\doc.kml'
  for line in zf.read("doc.kml").split("\n"):
    with open(temp,'a') as wf: #Create the doc.kml...

# %%
import pprint
# Load tables into feature collection
#points = ee.FeatureCollection('ft:10q302Kafv_V_Le-jm1Cj274Ejz0kTsSWTKNxf3br').remap([1, 2, 3,4], [0, 1, 2, 3], "class")
## https://fusiontables.google.com/data?docid=10q302Kafv_V_Le-jm1Cj274Ejz0kTsSWTKNxf3br
# points = ee.FeatureCollection('ft:1p-YuR8JdqopYb-LrUxb43xzGHQyKmhGr1EJU3wku').remap([1, 2, 3,4], [0, 1, 2, 3], "Name")
## find table in https://fusiontables.google.com/data?docid=1Axs89HgE3yIgPoTMxTjL965OYgtBrp2i1O2waz29#rows:id=1
# points = ee.FeatureCollection('ft:1Axs89HgE3yIgPoTMxTjL965OYgtBrp2i1O2waz29')
# 07/11 latest points. Finde here https://fusiontables.google.com/data?docid=1jHRNbgg-nvJ-TNJBjeB28apGsIvdrySp3WbL_PZG#rows:id=1
points = ee.FeatureCollection('ft:1jHRNbgg-nvJ-TNJBjeB28apGsIvdrySp3WbL_PZG')#.remap([1, 2, 3,4], [0, 1, 2, 3], "name")
        
pprint.pprint(points.getInfo())
# Out:
# {'columns': {'name': 'Number'},
#  'features': [{'geometry': {'coordinates': [-69.821972, 18.509205],
#                             'type': 'Point'},
#                'id': '2',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.814749, 18.514787],
#                             'type': 'Point'},
#                'id': '3',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.816642, 18.515114],
#                             'type': 'Point'},
#                'id': '4',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.821361, 18.51591],
#                             'type': 'Point'},
#                'id': '5',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.816524, 18.519229],
#                             'type': 'Point'},
#                'id': '6',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.815908, 18.513269],
#                             'type': 'Point'},
#                'id': '7',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.816694, 18.505315],
#                             'type': 'Point'},
#                'id': '8',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.831762, 18.517278],
#                             'type': 'Point'},
#                'id': '9',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.81428, 18.51724],
#                             'type': 'Point'},
#                'id': '10',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.820372, 18.512608],
#                             'type': 'Point'},
#                'id': '11',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.806788, 18.519296],
#                             'type': 'Point'},
#                'id': '12',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.951633, 18.461895],
#                             'type': 'Point'},
#                'id': '13',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.9596, 18.472335],
#                             'type': 'Point'},
#                'id': '14',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.936968, 18.469669],
#                             'type': 'Point'},
#                'id': '15',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.954235, 18.45906],
#                             'type': 'Point'},
#                'id': '16',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.963769, 18.477419],
#                             'type': 'Point'},
#                'id': '17',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.937196, 18.45595],
#                             'type': 'Point'},
#                'id': '18',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.938709, 18.466519],
#                             'type': 'Point'},
#                'id': '19',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.956277, 18.452715],
#                             'type': 'Point'},
#                'id': '20',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.970814, 18.455073],
#                             'type': 'Point'},
#                'id': '21',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.969901, 18.466218],
#                             'type': 'Point'},
#                'id': '22',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.940941, 18.472531],
#                             'type': 'Point'},
#                'id': '23',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.949841, 18.476388],
#                             'type': 'Point'},
#                'id': '24',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.942976, 18.459053],
#                             'type': 'Point'},
#                'id': '25',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.940496, 18.4622],
#                             'type': 'Point'},
#                'id': '26',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.949576, 18.471514],
#                             'type': 'Point'},
#                'id': '27',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.956436, 18.472049],
#                             'type': 'Point'},
#                'id': '28',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.955472, 18.476216],
#                             'type': 'Point'},
#                'id': '29',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.102737, 18.416443],
#                             'type': 'Point'},
#                'id': '30',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.094768, 18.417771],
#                             'type': 'Point'},
#                'id': '31',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.112949, 18.418543],
#                             'type': 'Point'},
#                'id': '32',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.098992, 18.423345],
#                             'type': 'Point'},
#                'id': '33',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.106103, 18.420695],
#                             'type': 'Point'},
#                'id': '34',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.09817, 18.412079],
#                             'type': 'Point'},
#                'id': '35',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.110336, 18.413652],
#                             'type': 'Point'},
#                'id': '36',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.102543, 18.428348],
#                             'type': 'Point'},
#                'id': '37',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.119178, 18.420881],
#                             'type': 'Point'},
#                'id': '38',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.108706, 18.428261],
#                             'type': 'Point'},
#                'id': '39',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.110495, 18.421637],
#                             'type': 'Point'},
#                'id': '40',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.111814, 18.410306],
#                             'type': 'Point'},
#                'id': '41',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.116966, 18.419412],
#                             'type': 'Point'},
#                'id': '42',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.115081, 18.410637],
#                             'type': 'Point'},
#                'id': '43',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.108972, 18.406518],
#                             'type': 'Point'},
#                'id': '44',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.22358, 19.005066],
#                             'type': 'Point'},
#                'id': '45',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.242181, 18.985895],
#                             'type': 'Point'},
#                'id': '46',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.253509, 18.964233],
#                             'type': 'Point'},
#                'id': '47',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.204733, 19.013975],
#                             'type': 'Point'},
#                'id': '48',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.229045, 19.014692],
#                             'type': 'Point'},
#                'id': '49',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.232121, 18.996778],
#                             'type': 'Point'},
#                'id': '50',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.211486, 19.007111],
#                             'type': 'Point'},
#                'id': '51',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.220725, 18.995318],
#                             'type': 'Point'},
#                'id': '52',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.255726, 18.958003],
#                             'type': 'Point'},
#                'id': '53',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.262018, 18.969447],
#                             'type': 'Point'},
#                'id': '54',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.196186, 19.023172],
#                             'type': 'Point'},
#                'id': '55',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.200775, 19.006041],
#                             'type': 'Point'},
#                'id': '56',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.249344, 18.980458],
#                             'type': 'Point'},
#                'id': '57',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.208564, 19.018922],
#                             'type': 'Point'},
#                'id': '58',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.256986, 18.952806],
#                             'type': 'Point'},
#                'id': '59',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.259343, 18.945925],
#                             'type': 'Point'},
#                'id': '60',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.212327, 19.001659],
#                             'type': 'Point'},
#                'id': '61',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.202497, 19.026048],
#                             'type': 'Point'},
#                'id': '62',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.412348, 19.089733],
#                             'type': 'Point'},
#                'id': '63',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.416008, 19.073537],
#                             'type': 'Point'},
#                'id': '64',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.419111, 19.063598],
#                             'type': 'Point'},
#                'id': '65',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.413906, 19.081677],
#                             'type': 'Point'},
#                'id': '66',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.411247, 19.096503],
#                             'type': 'Point'},
#                'id': '67',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.422628, 19.074148],
#                             'type': 'Point'},
#                'id': '68',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.418284, 19.06934],
#                             'type': 'Point'},
#                'id': '69',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.41453, 19.087508],
#                             'type': 'Point'},
#                'id': '70',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.415454, 19.078679],
#                             'type': 'Point'},
#                'id': '71',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.420515, 19.088975],
#                             'type': 'Point'},
#                'id': '72',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.411706, 19.093589],
#                             'type': 'Point'},
#                'id': '73',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.300283, 18.94475],
#                             'type': 'Point'},
#                'id': '74',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.305208, 18.948411],
#                             'type': 'Point'},
#                'id': '75',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.307606, 18.949222],
#                             'type': 'Point'},
#                'id': '76',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.295204, 18.939986],
#                             'type': 'Point'},
#                'id': '77',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.303014, 18.946751],
#                             'type': 'Point'},
#                'id': '78',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.264383, 18.928655],
#                             'type': 'Point'},
#                'id': '79',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.255978, 18.933985],
#                             'type': 'Point'},
#                'id': '80',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.255141, 18.939888],
#                             'type': 'Point'},
#                'id': '81',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.275647, 18.933038],
#                             'type': 'Point'},
#                'id': '82',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.285441, 18.932804],
#                             'type': 'Point'},
#                'id': '83',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.290551, 18.932273],
#                             'type': 'Point'},
#                'id': '84',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-70.280455, 18.93364],
#                             'type': 'Point'},
#                'id': '85',
#                'properties': {'name': 1.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.663285, 18.998048],
#                             'type': 'Point'},
#                'id': '86',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.624577, 18.959443],
#                             'type': 'Point'},
#                'id': '87',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.664716, 19.027993],
#                             'type': 'Point'},
#                'id': '88',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.556373, 19.001239],
#                             'type': 'Point'},
#                'id': '89',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.578844, 18.960953],
#                             'type': 'Point'},
#                'id': '90',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.656928, 18.976776],
#                             'type': 'Point'},
#                'id': '91',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.685513, 19.035533],
#                             'type': 'Point'},
#                'id': '92',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.582967, 19.029807],
#                             'type': 'Point'},
#                'id': '93',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.592504, 18.981252],
#                             'type': 'Point'},
#                'id': '94',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.63721, 19.012736],
#                             'type': 'Point'},
#                'id': '95',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.618995, 18.944567],
#                             'type': 'Point'},
#                'id': '96',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.70654, 19.050753],
#                             'type': 'Point'},
#                'id': '97',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.729037, 19.048065],
#                             'type': 'Point'},
#                'id': '98',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.642371, 18.927814],
#                             'type': 'Point'},
#                'id': '99',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.566216, 19.063227],
#                             'type': 'Point'},
#                'id': '100',
#                'properties': {'name': 2.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.792129, 19.128826],
#                             'type': 'Point'},
#                'id': '101',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.824209, 19.145076],
#                             'type': 'Point'},
#                'id': '102',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.842566, 19.153919],
#                             'type': 'Point'},
#                'id': '103',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.825663, 19.127828],
#                             'type': 'Point'},
#                'id': '104',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.830381, 19.163778],
#                             'type': 'Point'},
#                'id': '105',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.787367, 19.127386],
#                             'type': 'Point'},
#                'id': '106',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.877762, 19.150217],
#                             'type': 'Point'},
#                'id': '107',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.859477, 19.125795],
#                             'type': 'Point'},
#                'id': '108',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.783502, 19.135994],
#                             'type': 'Point'},
#                'id': '109',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.808439, 19.162643],
#                             'type': 'Point'},
#                'id': '110',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.819836, 19.121491],
#                             'type': 'Point'},
#                'id': '111',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.850754, 19.152154],
#                             'type': 'Point'},
#                'id': '112',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.848647, 19.164508],
#                             'type': 'Point'},
#                'id': '113',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.811777, 19.124929],
#                             'type': 'Point'},
#                'id': '114',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.889555, 19.137262],
#                             'type': 'Point'},
#                'id': '115',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.814134, 19.117472],
#                             'type': 'Point'},
#                'id': '116',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.830582, 19.151416],
#                             'type': 'Point'},
#                'id': '117',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.825183, 19.141218],
#                             'type': 'Point'},
#                'id': '118',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.897758, 19.133305],
#                             'type': 'Point'},
#                'id': '119',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.873361, 19.130235],
#                             'type': 'Point'},
#                'id': '120',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.840756, 19.134852],
#                             'type': 'Point'},
#                'id': '121',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.912755, 19.135817],
#                             'type': 'Point'},
#                'id': '122',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.799656, 19.123325],
#                             'type': 'Point'},
#                'id': '123',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.793555, 19.166821],
#                             'type': 'Point'},
#                'id': '124',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.894916, 19.157121],
#                             'type': 'Point'},
#                'id': '125',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.730643, 19.136927],
#                             'type': 'Point'},
#                'id': '126',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.712545, 19.140016],
#                             'type': 'Point'},
#                'id': '127',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.700902, 19.152258],
#                             'type': 'Point'},
#                'id': '128',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.743794, 19.141483],
#                             'type': 'Point'},
#                'id': '129',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.730053, 19.120132],
#                             'type': 'Point'},
#                'id': '130',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.714523, 19.155153],
#                             'type': 'Point'},
#                'id': '131',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.76677, 19.143844],
#                             'type': 'Point'},
#                'id': '132',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.722411, 19.129936],
#                             'type': 'Point'},
#                'id': '133',
#                'properties': {'name': 3.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.909927, 18.491363],
#                             'type': 'Point'},
#                'id': '134',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.867857, 18.489251],
#                             'type': 'Point'},
#                'id': '135',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.937942, 18.48928],
#                             'type': 'Point'},
#                'id': '136',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.944985, 18.472519],
#                             'type': 'Point'},
#                'id': '137',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.874961, 18.490659],
#                             'type': 'Point'},
#                'id': '138',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.904316, 18.511567],
#                             'type': 'Point'},
#                'id': '139',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.942074, 18.443741],
#                             'type': 'Point'},
#                'id': '140',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.927735, 18.499833],
#                             'type': 'Point'},
#                'id': '141',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.901013, 18.485635],
#                             'type': 'Point'},
#                'id': '142',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.894286, 18.491364],
#                             'type': 'Point'},
#                'id': '143',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.890719, 18.4916],
#                             'type': 'Point'},
#                'id': '144',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.906428, 18.486892],
#                             'type': 'Point'},
#                'id': '145',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.90177, 18.493476],
#                             'type': 'Point'},
#                'id': '146',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.911627, 18.488103],
#                             'type': 'Point'},
#                'id': '147',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.892892, 18.495631],
#                             'type': 'Point'},
#                'id': '148',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.913547, 18.494944],
#                             'type': 'Point'},
#                'id': '149',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.843915, 18.496048],
#                             'type': 'Point'},
#                'id': '150',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.843845, 18.501052],
#                             'type': 'Point'},
#                'id': '151',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.844586, 18.490147],
#                             'type': 'Point'},
#                'id': '152',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.834921, 18.501848],
#                             'type': 'Point'},
#                'id': '153',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.848359, 18.499167],
#                             'type': 'Point'},
#                'id': '154',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.850138, 18.501039],
#                             'type': 'Point'},
#                'id': '155',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.857023, 18.497365],
#                             'type': 'Point'},
#                'id': '156',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.843268, 18.493051],
#                             'type': 'Point'},
#                'id': '157',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.854017, 18.489478],
#                             'type': 'Point'},
#                'id': '158',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.830398, 18.501136],
#                             'type': 'Point'},
#                'id': '159',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.842101, 18.488293],
#                             'type': 'Point'},
#                'id': '160',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.859913, 18.493526],
#                             'type': 'Point'},
#                'id': '161',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.860088, 18.489548],
#                             'type': 'Point'},
#                'id': '162',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.856892, 18.488487],
#                             'type': 'Point'},
#                'id': '163',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.85039, 18.499156],
#                             'type': 'Point'},
#                'id': '164',
#                'properties': {'name': 4.0},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-69.86184, 18.496272],
#                             'type': 'Point'},
#                'id': '165',
#                'properties': {'name': 4.0},
#                'type': 'Feature'}],
#  'geo_column': 'geometry',
#  'id': 'ft:1jHRNbgg-nvJ-TNJBjeB28apGsIvdrySp3WbL_PZG',
#  'properties': {'DocID': '1jHRNbgg-nvJ-TNJBjeB28apGsIvdrySp3WbL_PZG',
#                 'name': 'trnPoints'},
#  'type': 'FeatureCollection'}

# %% [markdown]
# ## Extract cell values
#
# We need to extract the imagery cell values for each training point. This will produce a single table that associates pixels of each class with the spectral band values in those pixels.

# %%
# Sample the input imagery to get a FeatureCollection of training data.
training = spectral_indices_stack.sampleRegions(points,["name"],30)
pprint.pprint(training.getInfo())
# Out:
# {'columns': {},
#  'features': [{'geometry': None,
#                'id': '2_0',
#                'properties': {'B2': 699,
#                               'B2_mean': 688.5555555555554,
#                               'B3': 1130,
#                               'B3_mean': 1118.1111111111106,
#                               'B4': 1222,
#                               'B4_mean': 1247.8888888888887,
#                               'B5': 2226,
#                               'B5_mean': 2166.666666666666,
#                               'name': 4.0,
#                               'nd': 0.2911833},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '3_0',
#                'properties': {'B2': 1319,
#                               'B2_mean': 894.7777777777776,
#                               'B3': 1815,
#                               'B3_mean': 1361.8888888888887,
#                               'B4': 2095,
#                               'B4_mean': 1522.3333333333328,
#                               'B5': 2376,
#                               'B5_mean': 2386.555555555555,
#                               'name': 4.0,
#                               'nd': 0.06284948},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '4_0',
#                'properties': {'B2': 966,
#                               'B2_mean': 928.9999999999998,
#                               'B3': 1628,
#                               'B3_mean': 1479.1111111111109,
#                               'B4': 2027,
#                               'B4_mean': 1732.8888888888885,
#                               'B5': 2159,
#                               'B5_mean': 2099.2222222222217,
#                               'name': 4.0,
#                               'nd': 0.031533685},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '5_0',
#                'properties': {'B2': 552,
#                               'B2_mean': 668.5555555555553,
#                               'B3': 1081,
#                               'B3_mean': 1096.4444444444441,
#                               'B4': 1216,
#                               'B4_mean': 1185.6666666666663,
#                               'B5': 2446,
#                               'B5_mean': 2294.333333333333,
#                               'name': 4.0,
#                               'nd': 0.33588204},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '6_0',
#                'properties': {'B2': 1299,
#                               'B2_mean': 899.6666666666664,
#                               'B3': 2143,
#                               'B3_mean': 1395.1111111111109,
#                               'B4': 2406,
#                               'B4_mean': 1561.9999999999995,
#                               'B5': 3197,
#                               'B5_mean': 2755.9999999999995,
#                               'name': 4.0,
#                               'nd': 0.14117438},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '7_0',
#                'properties': {'B2': 987,
#                               'B2_mean': 980.1111111111109,
#                               'B3': 1499,
#                               'B3_mean': 1351.2222222222217,
#                               'B4': 1800,
#                               'B4_mean': 1570.1111111111109,
#                               'B5': 2171,
#                               'B5_mean': 2097.666666666666,
#                               'name': 4.0,
#                               'nd': 0.093427345},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '8_0',
#                'properties': {'B2': 1326,
#                               'B2_mean': 1265.6666666666663,
#                               'B3': 1757,
#                               'B3_mean': 1699.555555555555,
#                               'B4': 1970,
#                               'B4_mean': 1825.2222222222217,
#                               'B5': 2207,
#                               'B5_mean': 2143.111111111111,
#                               'name': 4.0,
#                               'nd': 0.056739286},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '9_0',
#                'properties': {'B2': 1098,
#                               'B2_mean': 790.333333333333,
#                               'B3': 1390,
#                               'B3_mean': 1146.5555555555552,
#                               'B4': 1587,
#                               'B4_mean': 1226.7777777777776,
#                               'B5': 2237,
#                               'B5_mean': 2454.777777777777,
#                               'name': 4.0,
#                               'nd': 0.16997908},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '10_0',
#                'properties': {'B2': 963,
#                               'B2_mean': 1263.9999999999998,
#                               'B3': 1739,
#                               'B3_mean': 2056.666666666666,
#                               'B4': 2052,
#                               'B4_mean': 2217.9999999999995,
#                               'B5': 3211,
#                               'B5_mean': 3203.7777777777765,
#                               'name': 4.0,
#                               'nd': 0.2202166},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '11_0',
#                'properties': {'B2': 1102,
#                               'B2_mean': 717.7777777777776,
#                               'B3': 1214,
#                               'B3_mean': 1039.1111111111106,
#                               'B4': 1224,
#                               'B4_mean': 1056.333333333333,
#                               'B5': 1925,
#                               'B5_mean': 2101.8888888888882,
#                               'name': 4.0,
#                               'nd': 0.22261035},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '12_0',
#                'properties': {'B2': 675,
#                               'B2_mean': 577.9999999999998,
#                               'B3': 1216,
#                               'B3_mean': 977.7777777777776,
#                               'B4': 1258,
#                               'B4_mean': 1037.1111111111106,
#                               'B5': 2227,
#                               'B5_mean': 2361.8888888888882,
#                               'name': 4.0,
#                               'nd': 0.27804878},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '13_0',
#                'properties': {'B2': 1261,
#                               'B2_mean': 1038.4444444444441,
#                               'B3': 1427,
#                               'B3_mean': 1340.6666666666663,
#                               'B4': 1567,
#                               'B4_mean': 1417.6666666666663,
#                               'B5': 1875,
#                               'B5_mean': 2068.444444444444,
#                               'name': 4.0,
#                               'nd': 0.08948286},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '14_0',
#                'properties': {'B2': 1050,
#                               'B2_mean': 1007.6666666666665,
#                               'B3': 1511,
#                               'B3_mean': 1292.9999999999998,
#                               'B4': 1508,
#                               'B4_mean': 1430.9999999999998,
#                               'B5': 2550,
#                               'B5_mean': 2234.166666666666,
#                               'name': 4.0,
#                               'nd': 0.25677675},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '15_0',
#                'properties': {'B2': 426,
#                               'B2_mean': 916.4444444444442,
#                               'B3': 887,
#                               'B3_mean': 1165.6666666666663,
#                               'B4': 870,
#                               'B4_mean': 1256.9999999999995,
#                               'B5': 1375,
#                               'B5_mean': 1882.5555555555547,
#                               'name': 4.0,
#                               'nd': 0.22494432},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '16_0',
#                'properties': {'B2': 930,
#                               'B2_mean': 1187.5555555555554,
#                               'B3': 996,
#                               'B3_mean': 1489.5555555555552,
#                               'B4': 1175,
#                               'B4_mean': 1622.444444444444,
#                               'B5': 2067,
#                               'B5_mean': 2209.8888888888887,
#                               'name': 4.0,
#                               'nd': 0.2751388},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '17_0',
#                'properties': {'B2': 2256,
#                               'B2_mean': 1770.8888888888882,
#                               'B3': 2748,
#                               'B3_mean': 2193.444444444444,
#                               'B4': 3021,
#                               'B4_mean': 2345.2222222222217,
#                               'B5': 4066,
#                               'B5_mean': 3189.11111111111,
#                               'name': 4.0,
#                               'nd': 0.14745308},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '18_0',
#                'properties': {'B2': 2354,
#                               'B2_mean': 1755.8888888888882,
#                               'B3': 2886,
#                               'B3_mean': 2119.111111111111,
#                               'B4': 3032,
#                               'B4_mean': 2281.2222222222213,
#                               'B5': 3121,
#                               'B5_mean': 2838.5555555555547,
#                               'name': 4.0,
#                               'nd': 0.014464489},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '19_0',
#                'properties': {'B2': 757,
#                               'B2_mean': 807.5555555555552,
#                               'B3': 962,
#                               'B3_mean': 1034.6666666666663,
#                               'B4': 1025,
#                               'B4_mean': 1120.333333333333,
#                               'B5': 1587,
#                               'B5_mean': 1705.666666666666,
#                               'name': 4.0,
#                               'nd': 0.2151608},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '20_0',
#                'properties': {'B2': 1115,
#                               'B2_mean': 1341.5555555555554,
#                               'B3': 1490,
#                               'B3_mean': 1571.1111111111106,
#                               'B4': 1517,
#                               'B4_mean': 1695.555555555555,
#                               'B5': 2026,
#                               'B5_mean': 2571.777777777777,
#                               'name': 4.0,
#                               'nd': 0.14366356},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '21_0',
#                'properties': {'B2': 2187,
#                               'B2_mean': 1787.9999999999995,
#                               'B3': 2620,
#                               'B3_mean': 2083.555555555555,
#                               'B4': 2740,
#                               'B4_mean': 2203.2222222222213,
#                               'B5': 2877,
#                               'B5_mean': 2465.777777777777,
#                               'name': 4.0,
#                               'nd': 0.024390243},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '22_0',
#                'properties': {'B2': 3979,
#                               'B2_mean': 3403.4444444444434,
#                               'B3': 4560,
#                               'B3_mean': 3976.2222222222213,
#                               'B4': 4782,
#                               'B4_mean': 4146.1111111111095,
#                               'B5': 4715,
#                               'B5_mean': 4158.11111111111,
#                               'name': 4.0,
#                               'nd': -0.0070548593},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '23_0',
#                'properties': {'B2': 2119,
#                               'B2_mean': 1331.7777777777776,
#                               'B3': 2208,
#                               'B3_mean': 1557.2222222222215,
#                               'B4': 2357,
#                               'B4_mean': 1618.6666666666663,
#                               'B5': 3060,
#                               'B5_mean': 2178.2222222222217,
#                               'name': 4.0,
#                               'nd': 0.12977663},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '24_0',
#                'properties': {'B2': 1080,
#                               'B2_mean': 899.6666666666664,
#                               'B3': 1481,
#                               'B3_mean': 1185.4444444444441,
#                               'B4': 1559,
#                               'B4_mean': 1253.8888888888887,
#                               'B5': 1746,
#                               'B5_mean': 1564.444444444444,
#                               'name': 4.0,
#                               'nd': 0.05658094},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '25_0',
#                'properties': {'B2': 775,
#                               'B2_mean': 918.5555555555552,
#                               'B3': 1193,
#                               'B3_mean': 1155.7777777777776,
#                               'B4': 1285,
#                               'B4_mean': 1326.5555555555552,
#                               'B5': 1364,
#                               'B5_mean': 1606.2222222222217,
#                               'name': 4.0,
#                               'nd': 0.029822575},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '26_0',
#                'properties': {'B2': 980,
#                               'B2_mean': 1252.9999999999998,
#                               'B3': 1287,
#                               'B3_mean': 1495.6666666666665,
#                               'B4': 1474,
#                               'B4_mean': 1655.1111111111104,
#                               'B5': 1915,
#                               'B5_mean': 2190.8888888888882,
#                               'name': 4.0,
#                               'nd': 0.13012688},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '27_0',
#                'properties': {'B2': 1332,
#                               'B2_mean': 1049.8888888888887,
#                               'B3': 1341,
#                               'B3_mean': 1357.7777777777774,
#                               'B4': 1448,
#                               'B4_mean': 1392.1111111111106,
#                               'B5': 3159,
#                               'B5_mean': 2897.5555555555547,
#                               'name': 4.0,
#                               'nd': 0.37139136},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '28_0',
#                'properties': {'B2': 1338,
#                               'B2_mean': 1246.6249999999995,
#                               'B3': 1545,
#                               'B3_mean': 1580.2499999999995,
#                               'B4': 1637,
#                               'B4_mean': 1661.3749999999998,
#                               'B5': 1929,
#                               'B5_mean': 2289.624999999999,
#                               'name': 4.0,
#                               'nd': 0.081884466},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '29_0',
#                'properties': {'B2': 1313,
#                               'B2_mean': 1089.5555555555552,
#                               'B3': 1621,
#                               'B3_mean': 1347.9999999999998,
#                               'B4': 1830,
#                               'B4_mean': 1439.222222222222,
#                               'B5': 2381,
#                               'B5_mean': 1978.2222222222215,
#                               'name': 4.0,
#                               'nd': 0.13084778},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '30_0',
#                'properties': {'B2': 681,
#                               'B2_mean': 705.6666666666665,
#                               'B3': 897,
#                               'B3_mean': 1115.222222222222,
#                               'B4': 1051,
#                               'B4_mean': 1355.2222222222217,
#                               'B5': 2895,
#                               'B5_mean': 2607.6666666666656,
#                               'name': 4.0,
#                               'nd': 0.46730867},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '31_0',
#                'properties': {'B2': 2437,
#                               'B2_mean': 1657.2222222222215,
#                               'B3': 3080,
#                               'B3_mean': 2242.9999999999995,
#                               'B4': 3657,
#                               'B4_mean': 2570.2222222222217,
#                               'B5': 4822,
#                               'B5_mean': 3870.11111111111,
#                               'name': 4.0,
#                               'nd': 0.13739827},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '32_0',
#                'properties': {'B2': 837,
#                               'B2_mean': 770.1111111111109,
#                               'B3': 1206,
#                               'B3_mean': 1089.333333333333,
#                               'B4': 1318,
#                               'B4_mean': 1201.4444444444441,
#                               'B5': 1888,
#                               'B5_mean': 2017.3333333333328,
#                               'name': 4.0,
#                               'nd': 0.17779164},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '33_0',
#                'properties': {'B2': 2230,
#                               'B2_mean': 1700.7777777777774,
#                               'B3': 2765,
#                               'B3_mean': 2150.111111111111,
#                               'B4': 3024,
#                               'B4_mean': 2353.2222222222217,
#                               'B5': 3357,
#                               'B5_mean': 2912.444444444444,
#                               'name': 4.0,
#                               'nd': 0.052186176},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '34_0',
#                'properties': {'B2': 2492,
#                               'B2_mean': 1700.555555555555,
#                               'B3': 3019,
#                               'B3_mean': 2091.1111111111104,
#                               'B4': 3191,
#                               'B4_mean': 2255.333333333333,
#                               'B5': 3325,
#                               'B5_mean': 2544.9999999999995,
#                               'name': 4.0,
#                               'nd': 0.020564763},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '35_0',
#                'properties': {'B2': 1889,
#                               'B2_mean': 1605.6666666666663,
#                               'B3': 2144,
#                               'B3_mean': 1938.7777777777774,
#                               'B4': 2275,
#                               'B4_mean': 2004.7777777777774,
#                               'B5': 2453,
#                               'B5_mean': 2374.333333333333,
#                               'name': 4.0,
#                               'nd': 0.037648056},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '36_0',
#                'properties': {'B2': 958,
#                               'B2_mean': 902.8888888888886,
#                               'B3': 1184,
#                               'B3_mean': 1167.8888888888887,
#                               'B4': 1291,
#                               'B4_mean': 1251.4444444444441,
#                               'B5': 1973,
#                               'B5_mean': 2146.8888888888882,
#                               'name': 4.0,
#                               'nd': 0.20894608},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '38_0',
#                'properties': {'B2': 1457,
#                               'B2_mean': 1372.9999999999998,
#                               'B3': 1959,
#                               'B3_mean': 1826.9999999999995,
#                               'B4': 2097,
#                               'B4_mean': 1940.9999999999993,
#                               'B5': 2439,
#                               'B5_mean': 2390.8888888888882,
#                               'name': 4.0,
#                               'nd': 0.07539683},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '39_0',
#                'properties': {'B2': 932,
#                               'B2_mean': 973.7777777777774,
#                               'B3': 1276,
#                               'B3_mean': 1396.6666666666667,
#                               'B4': 1402,
#                               'B4_mean': 1500.3333333333328,
#                               'B5': 1960,
#                               'B5_mean': 1916.1111111111106,
#                               'name': 4.0,
#                               'nd': 0.16597264},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '40_0',
#                'properties': {'B2': 867,
#                               'B2_mean': 643.5555555555554,
#                               'B3': 1221,
#                               'B3_mean': 960.1111111111109,
#                               'B4': 1363,
#                               'B4_mean': 1029.8888888888887,
#                               'B5': 2333,
#                               'B5_mean': 2151.9999999999995,
#                               'name': 4.0,
#                               'nd': 0.2624459},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '41_0',
#                'properties': {'B2': 1483,
#                               'B2_mean': 1055.222222222222,
#                               'B3': 2370,
#                               'B3_mean': 1478.8888888888887,
#                               'B4': 2283,
#                               'B4_mean': 1485.9999999999998,
#                               'B5': 3818,
#                               'B5_mean': 3275.444444444443,
#                               'name': 4.0,
#                               'nd': 0.2515981},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '42_0',
#                'properties': {'B2': 667,
#                               'B2_mean': 683.2222222222221,
#                               'B3': 878,
#                               'B3_mean': 953.9999999999999,
#                               'B4': 960,
#                               'B4_mean': 971.1111111111107,
#                               'B5': 2850,
#                               'B5_mean': 2676.8888888888887,
#                               'name': 4.0,
#                               'nd': 0.496063},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '43_0',
#                'properties': {'B2': 2043,
#                               'B2_mean': 1326.333333333333,
#                               'B3': 2389,
#                               'B3_mean': 1612.6666666666663,
#                               'B4': 2535,
#                               'B4_mean': 1686.1111111111104,
#                               'B5': 2735,
#                               'B5_mean': 2417.1111111111104,
#                               'name': 4.0,
#                               'nd': 0.037950665},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '44_0',
#                'properties': {'B2': 698,
#                               'B2_mean': 673.2222222222221,
#                               'B3': 1159,
#                               'B3_mean': 1037.9999999999998,
#                               'B4': 1249,
#                               'B4_mean': 1141.6666666666663,
#                               'B5': 2199,
#                               'B5_mean': 2230.9999999999995,
#                               'name': 4.0,
#                               'nd': 0.27552205},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '45_0',
#                'properties': {'B2': 249,
#                               'B2_mean': 245.8888888888888,
#                               'B3': 292,
#                               'B3_mean': 292.33333333333326,
#                               'B4': 142,
#                               'B4_mean': 141.88888888888886,
#                               'B5': 113,
#                               'B5_mean': 112.3333333333333,
#                               'name': 1.0,
#                               'nd': -0.11372549},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '46_0',
#                'properties': {'B2': 230,
#                               'B2_mean': 228.11111111111106,
#                               'B3': 286,
#                               'B3_mean': 287.8888888888888,
#                               'B4': 146,
#                               'B4_mean': 147.22222222222217,
#                               'B5': 139,
#                               'B5_mean': 140.66666666666663,
#                               'name': 1.0,
#                               'nd': -0.024561403},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '47_0',
#                'properties': {'B2': 269,
#                               'B2_mean': 263.33333333333326,
#                               'B3': 396,
#                               'B3_mean': 383.11111111111103,
#                               'B4': 219,
#                               'B4_mean': 213.6666666666666,
#                               'B5': 133,
#                               'B5_mean': 132.99999999999997,
#                               'name': 1.0,
#                               'nd': -0.24431819},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '48_0',
#                'properties': {'B2': 239,
#                               'B2_mean': 237.66666666666657,
#                               'B3': 264,
#                               'B3_mean': 261.11111111111103,
#                               'B4': 136,
#                               'B4_mean': 135.66666666666663,
#                               'B5': 114,
#                               'B5_mean': 117.66666666666663,
#                               'name': 1.0,
#                               'nd': -0.088},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '49_0',
#                'properties': {'B2': 325,
#                               'B2_mean': 324.99999999999994,
#                               'B3': 430,
#                               'B3_mean': 436.99999999999983,
#                               'B4': 211,
#                               'B4_mean': 214.99999999999994,
#                               'B5': 146,
#                               'B5_mean': 146.66666666666663,
#                               'name': 1.0,
#                               'nd': -0.18207283},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '50_0',
#                'properties': {'B2': 231,
#                               'B2_mean': 232.4444444444444,
#                               'B3': 285,
#                               'B3_mean': 279.4444444444444,
#                               'B4': 141,
#                               'B4_mean': 138.77777777777774,
#                               'B5': 122,
#                               'B5_mean': 123.88888888888886,
#                               'name': 1.0,
#                               'nd': -0.07224335},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '51_0',
#                'properties': {'B2': 228,
#                               'B2_mean': 228.99999999999994,
#                               'B3': 252,
#                               'B3_mean': 251.44444444444437,
#                               'B4': 130,
#                               'B4_mean': 127.77777777777774,
#                               'B5': 112,
#                               'B5_mean': 111.55555555555554,
#                               'name': 1.0,
#                               'nd': -0.07438017},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '52_0',
#                'properties': {'B2': 228,
#                               'B2_mean': 231.22222222222217,
#                               'B3': 289,
#                               'B3_mean': 286.99999999999994,
#                               'B4': 139,
#                               'B4_mean': 142.1111111111111,
#                               'B5': 126,
#                               'B5_mean': 124.66666666666664,
#                               'name': 1.0,
#                               'nd': -0.049056605},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '53_0',
#                'properties': {'B2': 308,
#                               'B2_mean': 306.66666666666663,
#                               'B3': 430,
#                               'B3_mean': 431.4444444444443,
#                               'B4': 277,
#                               'B4_mean': 276.5555555555555,
#                               'B5': 156,
#                               'B5_mean': 156.99999999999997,
#                               'name': 1.0,
#                               'nd': -0.27944574},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '54_0',
#                'properties': {'B2': 318,
#                               'B2_mean': 315.44444444444434,
#                               'B3': 500,
#                               'B3_mean': 493.3333333333332,
#                               'B4': 304,
#                               'B4_mean': 298.8888888888888,
#                               'B5': 163,
#                               'B5_mean': 160.77777777777774,
#                               'name': 1.0,
#                               'nd': -0.3019272},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '55_0',
#                'properties': {'B2': 226,
#                               'B2_mean': 225.99999999999994,
#                               'B3': 243,
#                               'B3_mean': 244.22222222222217,
#                               'B4': 122,
#                               'B4_mean': 123.11111111111109,
#                               'B5': 123,
#                               'B5_mean': 123.55555555555551,
#                               'name': 1.0,
#                               'nd': 0.0040816325},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '56_0',
#                'properties': {'B2': 226,
#                               'B2_mean': 229.6666666666666,
#                               'B3': 251,
#                               'B3_mean': 252.88888888888877,
#                               'B4': 129,
#                               'B4_mean': 128.99999999999997,
#                               'B5': 125,
#                               'B5_mean': 123.99999999999996,
#                               'name': 1.0,
#                               'nd': -0.015748031},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '57_0',
#                'properties': {'B2': 242,
#                               'B2_mean': 240.8888888888888,
#                               'B3': 321,
#                               'B3_mean': 318.8888888888888,
#                               'B4': 163,
#                               'B4_mean': 161.22222222222223,
#                               'B5': 141,
#                               'B5_mean': 141.55555555555551,
#                               'name': 1.0,
#                               'nd': -0.07236842},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '58_0',
#                'properties': {'B2': 245,
#                               'B2_mean': 246.88888888888886,
#                               'B3': 273,
#                               'B3_mean': 270.33333333333326,
#                               'B4': 140,
#                               'B4_mean': 143.2222222222222,
#                               'B5': 133,
#                               'B5_mean': 132.88888888888886,
#                               'name': 1.0,
#                               'nd': -0.025641026},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '59_0',
#                'properties': {'B2': 219,
#                               'B2_mean': 215.9999999999999,
#                               'B3': 250,
#                               'B3_mean': 250.99999999999991,
#                               'B4': 192,
#                               'B4_mean': 190.2222222222222,
#                               'B5': 199,
#                               'B5_mean': 207.8888888888888,
#                               'name': 1.0,
#                               'nd': 0.017902814},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '60_0',
#                'properties': {'B2': 640,
#                               'B2_mean': 608.6666666666666,
#                               'B3': 943,
#                               'B3_mean': 924.7777777777775,
#                               'B4': 1003,
#                               'B4_mean': 960.6666666666665,
#                               'B5': 2908,
#                               'B5_mean': 2976.666666666666,
#                               'name': 1.0,
#                               'nd': 0.4870877},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '61_0',
#                'properties': {'B2': 229,
#                               'B2_mean': 226.11111111111106,
#                               'B3': 264,
#                               'B3_mean': 264.11111111111103,
#                               'B4': 132,
#                               'B4_mean': 131.3333333333333,
#                               'B5': 112,
#                               'B5_mean': 111.88888888888886,
#                               'name': 1.0,
#                               'nd': -0.08196721},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '62_0',
#                'properties': {'B2': 244,
#                               'B2_mean': 242.99999999999994,
#                               'B3': 263,
#                               'B3_mean': 261.99999999999994,
#                               'B4': 135,
#                               'B4_mean': 135.88888888888886,
#                               'B5': 138,
#                               'B5_mean': 139.88888888888886,
#                               'name': 1.0,
#                               'nd': 0.010989011},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '63_0',
#                'properties': {'B2': 277,
#                               'B2_mean': 274.7777777777777,
#                               'B3': 333,
#                               'B3_mean': 330.9999999999999,
#                               'B4': 172,
#                               'B4_mean': 172.4444444444444,
#                               'B5': 170,
#                               'B5_mean': 169.99999999999997,
#                               'name': 1.0,
#                               'nd': -0.0058479533},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '64_0',
#                'properties': {'B2': 270,
#                               'B2_mean': 269.4444444444444,
#                               'B3': 310,
#                               'B3_mean': 308.88888888888886,
#                               'B4': 167,
#                               'B4_mean': 166.88888888888886,
#                               'B5': 170,
#                               'B5_mean': 170.22222222222217,
#                               'name': 1.0,
#                               'nd': 0.008902078},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '65_0',
#                'properties': {'B2': 287,
#                               'B2_mean': 283.6666666666666,
#                               'B3': 337,
#                               'B3_mean': 333.99999999999994,
#                               'B4': 201,
#                               'B4_mean': 197.33333333333326,
#                               'B5': 171,
#                               'B5_mean': 171.1111111111111,
#                               'name': 1.0,
#                               'nd': -0.08064516},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '66_0',
#                'properties': {'B2': 273,
#                               'B2_mean': 273.88888888888886,
#                               'B3': 322,
#                               'B3_mean': 322.4444444444444,
#                               'B4': 171,
#                               'B4_mean': 171.1111111111111,
#                               'B5': 177,
#                               'B5_mean': 176.11111111111106,
#                               'name': 1.0,
#                               'nd': 0.01724138},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '67_0',
#                'properties': {'B2': 293,
#                               'B2_mean': 292.6666666666666,
#                               'B3': 362,
#                               'B3_mean': 363.7777777777777,
#                               'B4': 181,
#                               'B4_mean': 180.99999999999997,
#                               'B5': 176,
#                               'B5_mean': 174.2222222222222,
#                               'name': 1.0,
#                               'nd': -0.014005602},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '68_0',
#                'properties': {'B2': 336,
#                               'B2_mean': 335.6666666666666,
#                               'B3': 448,
#                               'B3_mean': 447.6666666666665,
#                               'B4': 265,
#                               'B4_mean': 266.11111111111103,
#                               'B5': 188,
#                               'B5_mean': 191.22222222222217,
#                               'name': 1.0,
#                               'nd': -0.16997792},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '69_0',
#                'properties': {'B2': 273,
#                               'B2_mean': 273.7777777777777,
#                               'B3': 314,
#                               'B3_mean': 315.1111111111111,
#                               'B4': 180,
#                               'B4_mean': 174.66666666666666,
#                               'B5': 167,
#                               'B5_mean': 169.55555555555551,
#                               'name': 1.0,
#                               'nd': -0.037463978},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '70_0',
#                'properties': {'B2': 283,
#                               'B2_mean': 282.2222222222222,
#                               'B3': 357,
#                               'B3_mean': 352.3333333333332,
#                               'B4': 179,
#                               'B4_mean': 180.1111111111111,
#                               'B5': 177,
#                               'B5_mean': 176.55555555555551,
#                               'name': 1.0,
#                               'nd': -0.0056179776},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '71_0',
#                'properties': {'B2': 287,
#                               'B2_mean': 286.2222222222222,
#                               'B3': 332,
#                               'B3_mean': 336.11111111111103,
#                               'B4': 181,
#                               'B4_mean': 183.66666666666663,
#                               'B5': 183,
#                               'B5_mean': 179.55555555555551,
#                               'name': 1.0,
#                               'nd': 0.0054945056},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '72_0',
#                'properties': {'B2': 377,
#                               'B2_mean': 383.66666666666663,
#                               'B3': 520,
#                               'B3_mean': 537.2222222222221,
#                               'B4': 268,
#                               'B4_mean': 287.33333333333326,
#                               'B5': 225,
#                               'B5_mean': 242.77777777777771,
#                               'name': 1.0,
#                               'nd': -0.08722109},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '73_0',
#                'properties': {'B2': 304,
#                               'B2_mean': 304.2222222222222,
#                               'B3': 378,
#                               'B3_mean': 384.7777777777776,
#                               'B4': 194,
#                               'B4_mean': 191.99999999999997,
#                               'B5': 170,
#                               'B5_mean': 170.3333333333333,
#                               'name': 1.0,
#                               'nd': -0.06593407},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '74_0',
#                'properties': {'B2': 377,
#                               'B2_mean': 483.66666666666646,
#                               'B3': 566,
#                               'B3_mean': 689.5555555555554,
#                               'B4': 474,
#                               'B4_mean': 622.9999999999998,
#                               'B5': 669,
#                               'B5_mean': 994.6666666666664,
#                               'name': 1.0,
#                               'nd': 0.17060368},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '75_0',
#                'properties': {'B2': 329,
#                               'B2_mean': 371.11111111111103,
#                               'B3': 445,
#                               'B3_mean': 551.5555555555554,
#                               'B4': 339,
#                               'B4_mean': 459.9999999999999,
#                               'B5': 622,
#                               'B5_mean': 1374.4444444444441,
#                               'name': 1.0,
#                               'nd': 0.2944849},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '76_0',
#                'properties': {'B2': 274,
#                               'B2_mean': 449.5555555555555,
#                               'B3': 522,
#                               'B3_mean': 773.3333333333331,
#                               'B4': 442,
#                               'B4_mean': 741.8888888888886,
#                               'B5': 1132,
#                               'B5_mean': 1893.3333333333328,
#                               'name': 1.0,
#                               'nd': 0.43837357},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '77_0',
#                'properties': {'B2': 337,
#                               'B2_mean': 387.111111111111,
#                               'B3': 450,
#                               'B3_mean': 556.4444444444443,
#                               'B4': 359,
#                               'B4_mean': 466.111111111111,
#                               'B5': 540,
#                               'B5_mean': 1231.222222222222,
#                               'name': 1.0,
#                               'nd': 0.20133482},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '78_0',
#                'properties': {'B2': 348,
#                               'B2_mean': 365.8888888888888,
#                               'B3': 456,
#                               'B3_mean': 545.3333333333333,
#                               'B4': 355,
#                               'B4_mean': 465.44444444444423,
#                               'B5': 338,
#                               'B5_mean': 999.1111111111109,
#                               'name': 1.0,
#                               'nd': -0.024531025},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '79_0',
#                'properties': {'B2': 345,
#                               'B2_mean': 351.99999999999994,
#                               'B3': 669,
#                               'B3_mean': 631.6666666666664,
#                               'B4': 647,
#                               'B4_mean': 593.6666666666665,
#                               'B5': 1531,
#                               'B5_mean': 1509.5555555555557,
#                               'name': 1.0,
#                               'nd': 0.40587696},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '80_0',
#                'properties': {'B2': 382,
#                               'B2_mean': 504.44444444444423,
#                               'B3': 557,
#                               'B3_mean': 685.6666666666665,
#                               'B4': 508,
#                               'B4_mean': 658.5555555555554,
#                               'B5': 570,
#                               'B5_mean': 910.5555555555552,
#                               'name': 1.0,
#                               'nd': 0.057513915},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '81_0',
#                'properties': {'B2': 533,
#                               'B2_mean': 545.2222222222221,
#                               'B3': 894,
#                               'B3_mean': 874.4444444444441,
#                               'B4': 881,
#                               'B4_mean': 843.5555555555553,
#                               'B5': 1905,
#                               'B5_mean': 1698.7777777777771,
#                               'name': 1.0,
#                               'nd': 0.36755204},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '82_0',
#                'properties': {'B2': 325,
#                               'B2_mean': 318.2222222222222,
#                               'B3': 417,
#                               'B3_mean': 477.4444444444443,
#                               'B4': 327,
#                               'B4_mean': 397.6666666666665,
#                               'B5': 223,
#                               'B5_mean': 586.111111111111,
#                               'name': 1.0,
#                               'nd': -0.18909091},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '83_0',
#                'properties': {'B2': 434,
#                               'B2_mean': 464.7777777777776,
# ...
#               {'geometry': None,
#                'id': '140_0',
#                'properties': {'B2': 1487,
#                               'B2_mean': 1481.9999999999998,
#                               'B3': 1983,
#                               'B3_mean': 1751.666666666666,
#                               'B4': 2053,
#                               'B4_mean': 1891.1111111111104,
#                               'B5': 2799,
#                               'B5_mean': 2686.222222222222,
#                               'name': 4.0,
#                               'nd': 0.15375103},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '141_0',
#                'properties': {'B2': 479,
#                               'B2_mean': 475.8888888888888,
#                               'B3': 480,
#                               'B3_mean': 457.111111111111,
#                               'B4': 387,
#                               'B4_mean': 369.4444444444444,
#                               'B5': 488,
#                               'B5_mean': 454.9999999999999,
#                               'name': 4.0,
#                               'nd': 0.115428574},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '142_0',
#                'properties': {'B2': 639,
#                               'B2_mean': 699.6666666666665,
#                               'B3': 897,
#                               'B3_mean': 993.333333333333,
#                               'B4': 999,
#                               'B4_mean': 1089.4444444444441,
#                               'B5': 1543,
#                               'B5_mean': 1724.9999999999995,
#                               'name': 4.0,
#                               'nd': 0.21400473},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '143_0',
#                'properties': {'B2': 744,
#                               'B2_mean': 706.2222222222221,
#                               'B3': 1070,
#                               'B3_mean': 1057.6666666666663,
#                               'B4': 1208,
#                               'B4_mean': 1144.7777777777774,
#                               'B5': 1641,
#                               'B5_mean': 1717.7777777777771,
#                               'name': 4.0,
#                               'nd': 0.15198316},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '144_0',
#                'properties': {'B2': 1000,
#                               'B2_mean': 919.7777777777774,
#                               'B3': 1669,
#                               'B3_mean': 1393.8888888888885,
#                               'B4': 2209,
#                               'B4_mean': 1728.9999999999993,
#                               'B5': 3082,
#                               'B5_mean': 2545.7777777777774,
#                               'name': 4.0,
#                               'nd': 0.16499716},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '145_0',
#                'properties': {'B2': 989,
#                               'B2_mean': 801.6666666666664,
#                               'B3': 1259,
#                               'B3_mean': 1091.7777777777776,
#                               'B4': 1375,
#                               'B4_mean': 1174.5555555555554,
#                               'B5': 1741,
#                               'B5_mean': 1694.555555555555,
#                               'name': 4.0,
#                               'nd': 0.11745828},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '146_0',
#                'properties': {'B2': 776,
#                               'B2_mean': 669.9999999999999,
#                               'B3': 964,
#                               'B3_mean': 967.5555555555552,
#                               'B4': 1029,
#                               'B4_mean': 1007.1111111111109,
#                               'B5': 1583,
#                               'B5_mean': 1857.444444444444,
#                               'name': 4.0,
#                               'nd': 0.212098},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '147_0',
#                'properties': {'B2': 708,
#                               'B2_mean': 678.5555555555555,
#                               'B3': 1022,
#                               'B3_mean': 898.3333333333333,
#                               'B4': 1076,
#                               'B4_mean': 975.9999999999998,
#                               'B5': 1795,
#                               'B5_mean': 1801.3333333333326,
#                               'name': 4.0,
#                               'nd': 0.25043538},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '148_0',
#                'properties': {'B2': 654,
#                               'B2_mean': 651.6666666666665,
#                               'B3': 1040,
#                               'B3_mean': 972.9999999999997,
#                               'B4': 1084,
#                               'B4_mean': 1071.4444444444441,
#                               'B5': 1749,
#                               'B5_mean': 1760.333333333333,
#                               'name': 4.0,
#                               'nd': 0.23473349},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '149_0',
#                'properties': {'B2': 1984,
#                               'B2_mean': 1794.8888888888882,
#                               'B3': 2594,
#                               'B3_mean': 2215.999999999999,
#                               'B4': 2680,
#                               'B4_mean': 2383.222222222222,
#                               'B5': 2577,
#                               'B5_mean': 2429.5555555555543,
#                               'name': 4.0,
#                               'nd': -0.019592924},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '150_0',
#                'properties': {'B2': 1469,
#                               'B2_mean': 1406.5555555555552,
#                               'B3': 1908,
#                               'B3_mean': 1820.1111111111106,
#                               'B4': 2031,
#                               'B4_mean': 1987.3333333333328,
#                               'B5': 2179,
#                               'B5_mean': 2329.666666666666,
#                               'name': 4.0,
#                               'nd': 0.035154395},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '151_0',
#                'properties': {'B2': 1573,
#                               'B2_mean': 1093.333333333333,
#                               'B3': 2147,
#                               'B3_mean': 1650.444444444444,
#                               'B4': 2398,
#                               'B4_mean': 1854.333333333333,
#                               'B5': 2412,
#                               'B5_mean': 2195.777777777777,
#                               'name': 4.0,
#                               'nd': 0.0029106028},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '152_0',
#                'properties': {'B2': 1301,
#                               'B2_mean': 1230.222222222222,
#                               'B3': 1743,
#                               'B3_mean': 1597.5555555555547,
#                               'B4': 1996,
#                               'B4_mean': 1826.8888888888885,
#                               'B5': 2433,
#                               'B5_mean': 2345.666666666666,
#                               'name': 4.0,
#                               'nd': 0.09866787},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '153_0',
#                'properties': {'B2': 1398,
#                               'B2_mean': 1450.8888888888882,
#                               'B3': 1772,
#                               'B3_mean': 1795.7777777777774,
#                               'B4': 1871,
#                               'B4_mean': 1947.7777777777771,
#                               'B5': 2687,
#                               'B5_mean': 2702.7777777777774,
#                               'name': 4.0,
#                               'nd': 0.17902589},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '154_0',
#                'properties': {'B2': 1147,
#                               'B2_mean': 907.5555555555552,
#                               'B3': 1744,
#                               'B3_mean': 1301.4444444444443,
#                               'B4': 1814,
#                               'B4_mean': 1408.3333333333333,
#                               'B5': 1927,
#                               'B5_mean': 1781.6666666666665,
#                               'name': 4.0,
#                               'nd': 0.030205827},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '155_0',
#                'properties': {'B2': 1434,
#                               'B2_mean': 1340.7777777777774,
#                               'B3': 1970,
#                               'B3_mean': 1832.666666666666,
#                               'B4': 2312,
#                               'B4_mean': 2110.666666666666,
#                               'B5': 2614,
#                               'B5_mean': 2624.8888888888882,
#                               'name': 4.0,
#                               'nd': 0.06130735},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '156_0',
#                'properties': {'B2': 1324,
#                               'B2_mean': 1147.5555555555554,
#                               'B3': 1536,
#                               'B3_mean': 1452.7777777777774,
#                               'B4': 1661,
#                               'B4_mean': 1596.1111111111106,
#                               'B5': 2121,
#                               'B5_mean': 2164.333333333333,
#                               'name': 4.0,
#                               'nd': 0.12162877},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '157_0',
#                'properties': {'B2': 1496,
#                               'B2_mean': 1158.4444444444441,
#                               'B3': 1920,
#                               'B3_mean': 1462.333333333333,
#                               'B4': 2198,
#                               'B4_mean': 1609.1111111111104,
#                               'B5': 2655,
#                               'B5_mean': 2427.8888888888887,
#                               'name': 4.0,
#                               'nd': 0.09416856},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '158_0',
#                'properties': {'B2': 870,
#                               'B2_mean': 795.8888888888886,
#                               'B3': 1477,
#                               'B3_mean': 1169.5555555555552,
#                               'B4': 1630,
#                               'B4_mean': 1270.9999999999995,
#                               'B5': 1850,
#                               'B5_mean': 2114.2222222222217,
#                               'name': 4.0,
#                               'nd': 0.06321839},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '159_0',
#                'properties': {'B2': 2100,
#                               'B2_mean': 1534.8888888888887,
#                               'B3': 2510,
#                               'B3_mean': 1940.666666666666,
#                               'B4': 2544,
#                               'B4_mean': 2057.555555555555,
#                               'B5': 2345,
#                               'B5_mean': 2294.666666666666,
#                               'name': 4.0,
#                               'nd': -0.04070362},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '160_0',
#                'properties': {'B2': 1678,
#                               'B2_mean': 1446.333333333333,
#                               'B3': 1895,
#                               'B3_mean': 1772.8888888888885,
#                               'B4': 2047,
#                               'B4_mean': 1954.8888888888882,
#                               'B5': 3220,
#                               'B5_mean': 2843.444444444444,
#                               'name': 4.0,
#                               'nd': 0.22270742},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '161_0',
#                'properties': {'B2': 804,
#                               'B2_mean': 776.8888888888886,
#                               'B3': 939,
#                               'B3_mean': 1060.6666666666665,
#                               'B4': 1081,
#                               'B4_mean': 1155.222222222222,
#                               'B5': 2270,
#                               'B5_mean': 2334.999999999999,
#                               'name': 4.0,
#                               'nd': 0.35481945},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '162_0',
#                'properties': {'B2': 1145,
#                               'B2_mean': 983.6666666666665,
#                               'B3': 1433,
#                               'B3_mean': 1231.222222222222,
#                               'B4': 1581,
#                               'B4_mean': 1342.1111111111109,
#                               'B5': 2263,
#                               'B5_mean': 2137.444444444444,
#                               'name': 4.0,
#                               'nd': 0.17741935},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '163_0',
#                'properties': {'B2': 1548,
#                               'B2_mean': 1272.7777777777776,
#                               'B3': 2003,
#                               'B3_mean': 1607.8888888888885,
#                               'B4': 2281,
#                               'B4_mean': 1767.1111111111104,
#                               'B5': 3228,
#                               'B5_mean': 2742.2222222222217,
#                               'name': 4.0,
#                               'nd': 0.17190053},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '164_0',
#                'properties': {'B2': 1689,
#                               'B2_mean': 1234.1111111111109,
#                               'B3': 2050,
#                               'B3_mean': 1558.6666666666658,
#                               'B4': 2151,
#                               'B4_mean': 1656.8888888888882,
#                               'B5': 2470,
#                               'B5_mean': 2138.4444444444443,
#                               'name': 4.0,
#                               'nd': 0.06903268},
#                'type': 'Feature'},
#               {'geometry': None,
#                'id': '165_0',
#                'properties': {'B2': 1780,
#                               'B2_mean': 1208.6666666666665,
#                               'B3': 2061,
#                               'B3_mean': 1508.8888888888882,
#                               'B4': 2239,
#                               'B4_mean': 1645.7777777777774,
#                               'B5': 2725,
#                               'B5_mean': 2365.8888888888882,
#                               'name': 4.0,
#                               'nd': 0.09790491},
#                'type': 'Feature'}],
#  'properties': {'band_order': ['B2',
#                                'B3',
#                                'B4',
#                                'B5',
#                                'nd',
#                                'B2_mean',
#                                'B3_mean',
#                                'B4_mean',
#                                'B5_mean']},
#  'type': 'FeatureCollection'}

# %% [markdown]
# ## Train classifier
#
# We now have our imagery and our training data and it's time to run the random forests classification.

# %%
# Make a Random Forest classifier and train it.
rf = ee.Classifier.randomForest(10).train(training, ["name"])
# cart = ee.Classifier.cart().train(training,["landcover"],bands)
print(rf)
# Out:
# ee.Classifier({
#   "type": "Invocation",
#   "arguments": {
#     "classifier": {
#       "type": "Invocation",
#       "arguments": {
#         "numberOfTrees": 10
#       },
#       "functionName": "Classifier.randomForest"
#     },
#     "features": {
#       "type": "Invocation",
#       "arguments": {
#         "image": {
#           "type": "Invocation",
#           "arguments": {
#             "dstImg": {
#               "type": "Invocation",
#               "arguments": {
#                 "dstImg": {
#                   "type": "Invocation",
#                   "arguments": {
#                     "input": {
#                       "type": "Invocation",
#                       "arguments": {
#                         "collection": {
#                           "type": "Invocation",
#                           "arguments": {
#                             "collection": {
#                               "type": "Invocation",
#                               "arguments": {
#                                 "collection": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "collection": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "collection": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "id": "LANDSAT/LC08/C01/T1_SR"
#                                           },
#                                           "functionName": "ImageCollection.load"
#                                         },
#                                         "key": "CLOUD_COVER"
#                                       },
#                                       "functionName": "Collection.limit"
#                                     },
#                                     "baseAlgorithm": {
#                                       "type": "Function",
#                                       "argumentNames": [
#                                         "_MAPPING_VAR_0_0"
#                                       ],
#                                       "body": {
#                                         "type": "Invocation",
#                                         "arguments": {
#                                           "destination": {
#                                             "type": "Invocation",
#                                             "arguments": {
#                                               "input": {
#                                                 "type": "Invocation",
#                                                 "arguments": {
#                                                   "image": {
#                                                     "type": "ArgumentRef",
#                                                     "value": "_MAPPING_VAR_0_0"
#                                                   },
#                                                   "mask": {
#                                                     "type": "Invocation",
#                                                     "arguments": {
#                                                       "image1": {
#                                                         "type": "Invocation",
#                                                         "arguments": {
#                                                           "image1": {
#                                                             "type": "Invocation",
#                                                             "arguments": {
#                                                               "input": {
#                                                                 "type": "ArgumentRef",
#                                                                 "value": "_MAPPING_VAR_0_0"
#                                                               },
#                                                               "bandSelectors": [
#                                                                 "pixel_qa"
#                                                               ]
#                                                             },
#                                                             "functionName": "Image.select"
#                                                           },
#                                                           "image2": {
#                                                             "type": "Invocation",
#                                                             "arguments": {
#                                                               "value": 32
#                                                             },
#                                                             "functionName": "Image.constant"
#                                                           }
#                                                         },
#                                                         "functionName": "Image.bitwiseAnd"
#                                                       },
#                                                       "image2": {
#                                                         "type": "Invocation",
#                                                         "arguments": {
#                                                           "value": 0
#                                                         },
#                                                         "functionName": "Image.constant"
#                                                       }
#                                                     },
#                                                     "functionName": "Image.eq"
#                                                   }
#                                                 },
#                                                 "functionName": "Image.updateMask"
#                                               },
#                                               "bandSelectors": [
#                                                 "B[0-9]*"
#                                               ]
#                                             },
#                                             "functionName": "Image.select"
#                                           },
#                                           "source": {
#                                             "type": "ArgumentRef",
#                                             "value": "_MAPPING_VAR_0_0"
#                                           },
#                                           "properties": [
#                                             "system:time_start"
#                                           ]
#                                         },
#                                         "functionName": "Image.copyProperties"
#                                       }
#                                     }
#                                   },
#                                   "functionName": "Collection.map"
#                                 },
#                                 "filter": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "rightField": "system:time_start",
#                                     "leftValue": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "start": "2015-01-01",
#                                         "end": "2019-12-30"
#                                       },
#                                       "functionName": "DateRange"
#                                     }
#                                   },
#                                   "functionName": "Filter.dateRangeContains"
#                                 }
#                               },
#                               "functionName": "Collection.filter"
#                             },
#                             "filter": {
#                               "type": "Invocation",
#                               "arguments": {
#                                 "leftField": ".all",
#                                 "rightValue": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "geometry": {
#                                       "type": "Point",
#                                       "coordinates": [
#                                         -70.0522,
#                                         18.749
#                                       ]
#                                     }
#                                   },
#                                   "functionName": "Feature"
#                                 }
#                               },
#                               "functionName": "Filter.intersects"
#                             }
#                           },
#                           "functionName": "Collection.filter"
#                         }
#                       },
#                       "functionName": "Collection.first"
#                     },
#                     "bandSelectors": [
#                       "B[2-5]"
#                     ]
#                   },
#                   "functionName": "Image.select"
#                 },
#                 "srcImg": {
#                   "type": "Invocation",
#                   "arguments": {
#                     "input": {
#                       "type": "Invocation",
#                       "arguments": {
#                         "input": {
#                           "type": "Invocation",
#                           "arguments": {
#                             "collection": {
#                               "type": "Invocation",
#                               "arguments": {
#                                 "collection": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "collection": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "collection": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "collection": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "id": "LANDSAT/LC08/C01/T1_SR"
#                                               },
#                                               "functionName": "ImageCollection.load"
#                                             },
#                                             "key": "CLOUD_COVER"
#                                           },
#                                           "functionName": "Collection.limit"
#                                         },
#                                         "baseAlgorithm": {
#                                           "type": "Function",
#                                           "argumentNames": [
#                                             "_MAPPING_VAR_0_0"
#                                           ],
#                                           "body": {
#                                             "type": "Invocation",
#                                             "arguments": {
#                                               "destination": {
#                                                 "type": "Invocation",
#                                                 "arguments": {
#                                                   "input": {
#                                                     "type": "Invocation",
#                                                     "arguments": {
#                                                       "image": {
#                                                         "type": "ArgumentRef",
#                                                         "value": "_MAPPING_VAR_0_0"
#                                                       },
#                                                       "mask": {
#                                                         "type": "Invocation",
#                                                         "arguments": {
#                                                           "image1": {
#                                                             "type": "Invocation",
#                                                             "arguments": {
#                                                               "image1": {
#                                                                 "type": "Invocation",
#                                                                 "arguments": {
#                                                                   "input": {
#                                                                     "type": "ArgumentRef",
#                                                                     "value": "_MAPPING_VAR_0_0"
#                                                                   },
#                                                                   "bandSelectors": [
#                                                                     "pixel_qa"
#                                                                   ]
#                                                                 },
#                                                                 "functionName": "Image.select"
#                                                               },
#                                                               "image2": {
#                                                                 "type": "Invocation",
#                                                                 "arguments": {
#                                                                   "value": 32
#                                                                 },
#                                                                 "functionName": "Image.constant"
#                                                               }
#                                                             },
#                                                             "functionName": "Image.bitwiseAnd"
#                                                           },
#                                                           "image2": {
#                                                             "type": "Invocation",
#                                                             "arguments": {
#                                                               "value": 0
#                                                             },
#                                                             "functionName": "Image.constant"
#                                                           }
#                                                         },
#                                                         "functionName": "Image.eq"
#                                                       }
#                                                     },
#                                                     "functionName": "Image.updateMask"
#                                                   },
#                                                   "bandSelectors": [
#                                                     "B[0-9]*"
#                                                   ]
#                                                 },
#                                                 "functionName": "Image.select"
#                                               },
#                                               "source": {
#                                                 "type": "ArgumentRef",
#                                                 "value": "_MAPPING_VAR_0_0"
#                                               },
#                                               "properties": [
#                                                 "system:time_start"
#                                               ]
#                                             },
#                                             "functionName": "Image.copyProperties"
#                                           }
#                                         }
#                                       },
#                                       "functionName": "Collection.map"
#                                     },
#                                     "filter": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "rightField": "system:time_start",
#                                         "leftValue": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "start": "2015-01-01",
#                                             "end": "2019-12-30"
#                                           },
#                                           "functionName": "DateRange"
#                                         }
#                                       },
#                                       "functionName": "Filter.dateRangeContains"
#                                     }
#                                   },
#                                   "functionName": "Collection.filter"
#                                 },
#                                 "filter": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "leftField": ".all",
#                                     "rightValue": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "geometry": {
#                                           "type": "Point",
#                                           "coordinates": [
#                                             -70.0522,
#                                             18.749
#                                           ]
#                                         }
#                                       },
#                                       "functionName": "Feature"
#                                     }
#                                   },
#                                   "functionName": "Filter.intersects"
#                                 }
#                               },
#                               "functionName": "Collection.filter"
#                             }
#                           },
#                           "functionName": "Collection.first"
#                         },
#                         "bandSelectors": [
#                           "B[2-5]"
#                         ]
#                       },
#                       "functionName": "Image.select"
#                     },
#                     "bandNames": [
#                       "B5",
#                       "B4"
#                     ]
#                   },
#                   "functionName": "Image.normalizedDifference"
#                 }
#               },
#               "functionName": "Image.addBands"
#             },
#             "srcImg": {
#               "type": "Invocation",
#               "arguments": {
#                 "image": {
#                   "type": "Invocation",
#                   "arguments": {
#                     "input": {
#                       "type": "Invocation",
#                       "arguments": {
#                         "collection": {
#                           "type": "Invocation",
#                           "arguments": {
#                             "collection": {
#                               "type": "Invocation",
#                               "arguments": {
#                                 "collection": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "collection": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "collection": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "id": "LANDSAT/LC08/C01/T1_SR"
#                                           },
#                                           "functionName": "ImageCollection.load"
#                                         },
#                                         "key": "CLOUD_COVER"
#                                       },
#                                       "functionName": "Collection.limit"
#                                     },
#                                     "baseAlgorithm": {
#                                       "type": "Function",
#                                       "argumentNames": [
#                                         "_MAPPING_VAR_0_0"
#                                       ],
#                                       "body": {
#                                         "type": "Invocation",
#                                         "arguments": {
#                                           "destination": {
#                                             "type": "Invocation",
#                                             "arguments": {
#                                               "input": {
#                                                 "type": "Invocation",
#                                                 "arguments": {
#                                                   "image": {
#                                                     "type": "ArgumentRef",
#                                                     "value": "_MAPPING_VAR_0_0"
#                                                   },
#                                                   "mask": {
#                                                     "type": "Invocation",
#                                                     "arguments": {
#                                                       "image1": {
#                                                         "type": "Invocation",
#                                                         "arguments": {
#                                                           "image1": {
#                                                             "type": "Invocation",
#                                                             "arguments": {
#                                                               "input": {
#                                                                 "type": "ArgumentRef",
#                                                                 "value": "_MAPPING_VAR_0_0"
#                                                               },
#                                                               "bandSelectors": [
#                                                                 "pixel_qa"
#                                                               ]
#                                                             },
#                                                             "functionName": "Image.select"
#                                                           },
#                                                           "image2": {
#                                                             "type": "Invocation",
#                                                             "arguments": {
#                                                               "value": 32
#                                                             },
#                                                             "functionName": "Image.constant"
#                                                           }
#                                                         },
#                                                         "functionName": "Image.bitwiseAnd"
#                                                       },
#                                                       "image2": {
#                                                         "type": "Invocation",
#                                                         "arguments": {
#                                                           "value": 0
#                                                         },
#                                                         "functionName": "Image.constant"
#                                                       }
#                                                     },
#                                                     "functionName": "Image.eq"
#                                                   }
#                                                 },
#                                                 "functionName": "Image.updateMask"
#                                               },
#                                               "bandSelectors": [
#                                                 "B[0-9]*"
#                                               ]
#                                             },
#                                             "functionName": "Image.select"
#                                           },
#                                           "source": {
#                                             "type": "ArgumentRef",
#                                             "value": "_MAPPING_VAR_0_0"
#                                           },
#                                           "properties": [
#                                             "system:time_start"
#                                           ]
#                                         },
#                                         "functionName": "Image.copyProperties"
#                                       }
#                                     }
#                                   },
#                                   "functionName": "Collection.map"
#                                 },
#                                 "filter": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "rightField": "system:time_start",
#                                     "leftValue": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "start": "2015-01-01",
#                                         "end": "2019-12-30"
#                                       },
#                                       "functionName": "DateRange"
#                                     }
#                                   },
#                                   "functionName": "Filter.dateRangeContains"
#                                 }
#                               },
#                               "functionName": "Collection.filter"
#                             },
#                             "filter": {
#                               "type": "Invocation",
#                               "arguments": {
#                                 "leftField": ".all",
#                                 "rightValue": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "geometry": {
#                                       "type": "Point",
#                                       "coordinates": [
#                                         -70.0522,
#                                         18.749
#                                       ]
#                                     }
#                                   },
#                                   "functionName": "Feature"
#                                 }
#                               },
#                               "functionName": "Filter.intersects"
#                             }
#                           },
#                           "functionName": "Collection.filter"
#                         }
#                       },
#                       "functionName": "Collection.first"
#                     },
#                     "bandSelectors": [
#                       "B[2-5]"
#                     ]
#                   },
#                   "functionName": "Image.select"
#                 },
#                 "reducer": {
#                   "type": "Invocation",
#                   "arguments": {},
#                   "functionName": "Reducer.mean"
#                 },
#                 "kernel": {
#                   "type": "Invocation",
#                   "arguments": {
#                     "radius": 1,
#                     "units": "pixels"
#                   },
#                   "functionName": "Kernel.square"
#                 }
#               },
#               "functionName": "Image.reduceNeighborhood"
#             }
#           },
#           "functionName": "Image.addBands"
#         },
#         "collection": {
#           "type": "Invocation",
#           "arguments": {
#             "tableId": "ft:1jHRNbgg-nvJ-TNJBjeB28apGsIvdrySp3WbL_PZG"
#           },
#           "functionName": "Collection.loadTable"
#         },
#         "properties": [
#           "name"
#         ],
#         "scale": 30
#       },
#       "functionName": "Image.sampleRegions"
#     },
#     "classProperty": [
#       "name"
#     ]
#   },
#   "functionName": "Classifier.train"
# })

# %%
# Classify the input imagery.
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg

result = spectral_indices_stack.classify(rf)
type(result)

# imgplot = plt.imshow(result)
#result_cart = image.select(bands).classify(cart)
#pprint.pprint(result.getInfo())
# Image(url=result.getThumbUrl({'min': 0, 'max': 3}))
#pp.pprint(spectral_indices_stack.getInfo())
# Out:
# ee.image.Image

# %%
#Create a slider widget to add both Landsat 8 and PlanetScope 4B SR imagery
map1 = ipyleaflet.Map(
    center=(18.7490, -70.0522), zoom=12,
    layout={'height':'500px'},
)
# ps4bsr_tile_url=GetTileLayerUrl(ps4bsr.median().visualize(min=0, max=3, bands=['b4', 'b3', 'b2']))
l8sr_tile_url = GetTileLayerUrl(result().visualize(min=0, max=3, gamma=1.5))  #Landsat 8 SR
# left = ipyleaflet.TileLayer(url=ps4bsr_tile_url)
right=ipyleaflet.TileLayer(url=l8sr_tile_url)
control = ipyleaflet.SplitMapControl(right_layer=right)
map1.add_control(control)
map1

# %%
import ipywidgets

# %%
#region = boundary.geometry().bounds().getInfo()['coordinates'][0]
task = ee.batch.Export.image.toDrive(
  image = result,
  description = "LCimage",
  #assetId = 'users/ximenamesa/LC' + "DR",
  maxPixels = 100000000,   
  #region = region,
  scale = 2)
task.start()
print("Task started")

# %%
# clas_col = ','.join(['red','green','blue','pink'])   
Image(result({'min': 0, 'max': 3}))

# %% [markdown]
# ## Other Classifiers
#
# Try some other classifiers in GEE to see if the result is better or different.

# %% [markdown]
# ## Accuracy Assessment
#
# The final aspect of the classification is an unbiased estimate of the overall and class specific classification accuracy. For the accuracy assessment we will use a stratified random sampling procedure where the number of samples is equal for all strata. It is also possible to sample based on inclusion probability of each stratum, which depends on the frequency of pixels of each stratum.
#
# ## Stratified Random Sampling by Land-Cover Class
#
# Before generating random pixels from the data frame we need to know how many pixels we need per class to evaluate a specified accuracy with an acceptable confidence of that estimate. To calculate the number of samples per class according to sampling theory to evaluate an accuracy refer to equation 26 on page 44 of the landCoverClassification_theory.

# %%
trainAccuracy = rf.confusionMatrix()
print('Rerror matrix: ', trainAccuracy)
print('Training overall accuracy: ', trainAccuracy.accuracy())
# Out:
# Rerror matrix:  ee.ConfusionMatrix({
#   "type": "Invocation",
#   "arguments": {
#     "array": {
#       "type": "Invocation",
#       "arguments": {
#         "classifier": {
#           "type": "Invocation",
#           "arguments": {
#             "classifier": {
#               "type": "Invocation",
#               "arguments": {
#                 "numberOfTrees": 10
#               },
#               "functionName": "Classifier.randomForest"
#             },
#             "features": {
#               "type": "Invocation",
#               "arguments": {
#                 "image": {
#                   "type": "Invocation",
#                   "arguments": {
#                     "dstImg": {
#                       "type": "Invocation",
#                       "arguments": {
#                         "dstImg": {
#                           "type": "Invocation",
#                           "arguments": {
#                             "input": {
#                               "type": "Invocation",
#                               "arguments": {
#                                 "collection": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "collection": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "collection": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "collection": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "collection": {
#                                                   "type": "Invocation",
#                                                   "arguments": {
#                                                     "id": "LANDSAT/LC08/C01/T1_SR"
#                                                   },
#                                                   "functionName": "ImageCollection.load"
#                                                 },
#                                                 "key": "CLOUD_COVER"
#                                               },
#                                               "functionName": "Collection.limit"
#                                             },
#                                             "baseAlgorithm": {
#                                               "type": "Function",
#                                               "argumentNames": [
#                                                 "_MAPPING_VAR_0_0"
#                                               ],
#                                               "body": {
#                                                 "type": "Invocation",
#                                                 "arguments": {
#                                                   "destination": {
#                                                     "type": "Invocation",
#                                                     "arguments": {
#                                                       "input": {
#                                                         "type": "Invocation",
#                                                         "arguments": {
#                                                           "image": {
#                                                             "type": "ArgumentRef",
#                                                             "value": "_MAPPING_VAR_0_0"
#                                                           },
#                                                           "mask": {
#                                                             "type": "Invocation",
#                                                             "arguments": {
#                                                               "image1": {
#                                                                 "type": "Invocation",
#                                                                 "arguments": {
#                                                                   "image1": {
#                                                                     "type": "Invocation",
#                                                                     "arguments": {
#                                                                       "input": {
#                                                                         "type": "ArgumentRef",
#                                                                         "value": "_MAPPING_VAR_0_0"
#                                                                       },
#                                                                       "bandSelectors": [
#                                                                         "pixel_qa"
#                                                                       ]
#                                                                     },
#                                                                     "functionName": "Image.select"
#                                                                   },
#                                                                   "image2": {
#                                                                     "type": "Invocation",
#                                                                     "arguments": {
#                                                                       "value": 32
#                                                                     },
#                                                                     "functionName": "Image.constant"
#                                                                   }
#                                                                 },
#                                                                 "functionName": "Image.bitwiseAnd"
#                                                               },
#                                                               "image2": {
#                                                                 "type": "Invocation",
#                                                                 "arguments": {
#                                                                   "value": 0
#                                                                 },
#                                                                 "functionName": "Image.constant"
#                                                               }
#                                                             },
#                                                             "functionName": "Image.eq"
#                                                           }
#                                                         },
#                                                         "functionName": "Image.updateMask"
#                                                       },
#                                                       "bandSelectors": [
#                                                         "B[0-9]*"
#                                                       ]
#                                                     },
#                                                     "functionName": "Image.select"
#                                                   },
#                                                   "source": {
#                                                     "type": "ArgumentRef",
#                                                     "value": "_MAPPING_VAR_0_0"
#                                                   },
#                                                   "properties": [
#                                                     "system:time_start"
#                                                   ]
#                                                 },
#                                                 "functionName": "Image.copyProperties"
#                                               }
#                                             }
#                                           },
#                                           "functionName": "Collection.map"
#                                         },
#                                         "filter": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "rightField": "system:time_start",
#                                             "leftValue": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "start": "2015-01-01",
#                                                 "end": "2019-12-30"
#                                               },
#                                               "functionName": "DateRange"
#                                             }
#                                           },
#                                           "functionName": "Filter.dateRangeContains"
#                                         }
#                                       },
#                                       "functionName": "Collection.filter"
#                                     },
#                                     "filter": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "leftField": ".all",
#                                         "rightValue": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "geometry": {
#                                               "type": "Point",
#                                               "coordinates": [
#                                                 -70.0522,
#                                                 18.749
#                                               ]
#                                             }
#                                           },
#                                           "functionName": "Feature"
#                                         }
#                                       },
#                                       "functionName": "Filter.intersects"
#                                     }
#                                   },
#                                   "functionName": "Collection.filter"
#                                 }
#                               },
#                               "functionName": "Collection.first"
#                             },
#                             "bandSelectors": [
#                               "B[2-5]"
#                             ]
#                           },
#                           "functionName": "Image.select"
#                         },
#                         "srcImg": {
#                           "type": "Invocation",
#                           "arguments": {
#                             "input": {
#                               "type": "Invocation",
#                               "arguments": {
#                                 "input": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "collection": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "collection": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "collection": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "collection": {
#                                                   "type": "Invocation",
#                                                   "arguments": {
#                                                     "collection": {
#                                                       "type": "Invocation",
#                                                       "arguments": {
#                                                         "id": "LANDSAT/LC08/C01/T1_SR"
#                                                       },
#                                                       "functionName": "ImageCollection.load"
#                                                     },
#                                                     "key": "CLOUD_COVER"
#                                                   },
#                                                   "functionName": "Collection.limit"
#                                                 },
#                                                 "baseAlgorithm": {
#                                                   "type": "Function",
#                                                   "argumentNames": [
#                                                     "_MAPPING_VAR_0_0"
#                                                   ],
#                                                   "body": {
#                                                     "type": "Invocation",
#                                                     "arguments": {
#                                                       "destination": {
#                                                         "type": "Invocation",
#                                                         "arguments": {
#                                                           "input": {
#                                                             "type": "Invocation",
#                                                             "arguments": {
#                                                               "image": {
#                                                                 "type": "ArgumentRef",
#                                                                 "value": "_MAPPING_VAR_0_0"
#                                                               },
#                                                               "mask": {
#                                                                 "type": "Invocation",
#                                                                 "arguments": {
#                                                                   "image1": {
#                                                                     "type": "Invocation",
#                                                                     "arguments": {
#                                                                       "image1": {
#                                                                         "type": "Invocation",
#                                                                         "arguments": {
#                                                                           "input": {
#                                                                             "type": "ArgumentRef",
#                                                                             "value": "_MAPPING_VAR_0_0"
#                                                                           },
#                                                                           "bandSelectors": [
#                                                                             "pixel_qa"
#                                                                           ]
#                                                                         },
#                                                                         "functionName": "Image.select"
#                                                                       },
#                                                                       "image2": {
#                                                                         "type": "Invocation",
#                                                                         "arguments": {
#                                                                           "value": 32
#                                                                         },
#                                                                         "functionName": "Image.constant"
#                                                                       }
#                                                                     },
#                                                                     "functionName": "Image.bitwiseAnd"
#                                                                   },
#                                                                   "image2": {
#                                                                     "type": "Invocation",
#                                                                     "arguments": {
#                                                                       "value": 0
#                                                                     },
#                                                                     "functionName": "Image.constant"
#                                                                   }
#                                                                 },
#                                                                 "functionName": "Image.eq"
#                                                               }
#                                                             },
#                                                             "functionName": "Image.updateMask"
#                                                           },
#                                                           "bandSelectors": [
#                                                             "B[0-9]*"
#                                                           ]
#                                                         },
#                                                         "functionName": "Image.select"
#                                                       },
#                                                       "source": {
#                                                         "type": "ArgumentRef",
#                                                         "value": "_MAPPING_VAR_0_0"
#                                                       },
#                                                       "properties": [
#                                                         "system:time_start"
#                                                       ]
#                                                     },
#                                                     "functionName": "Image.copyProperties"
#                                                   }
#                                                 }
#                                               },
#                                               "functionName": "Collection.map"
#                                             },
#                                             "filter": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "rightField": "system:time_start",
#                                                 "leftValue": {
#                                                   "type": "Invocation",
#                                                   "arguments": {
#                                                     "start": "2015-01-01",
#                                                     "end": "2019-12-30"
#                                                   },
#                                                   "functionName": "DateRange"
#                                                 }
#                                               },
#                                               "functionName": "Filter.dateRangeContains"
#                                             }
#                                           },
#                                           "functionName": "Collection.filter"
#                                         },
#                                         "filter": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "leftField": ".all",
#                                             "rightValue": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "geometry": {
#                                                   "type": "Point",
#                                                   "coordinates": [
#                                                     -70.0522,
#                                                     18.749
#                                                   ]
#                                                 }
#                                               },
#                                               "functionName": "Feature"
#                                             }
#                                           },
#                                           "functionName": "Filter.intersects"
#                                         }
#                                       },
#                                       "functionName": "Collection.filter"
#                                     }
#                                   },
#                                   "functionName": "Collection.first"
#                                 },
#                                 "bandSelectors": [
#                                   "B[2-5]"
#                                 ]
#                               },
#                               "functionName": "Image.select"
#                             },
#                             "bandNames": [
#                               "B5",
#                               "B4"
#                             ]
#                           },
#                           "functionName": "Image.normalizedDifference"
#                         }
#                       },
#                       "functionName": "Image.addBands"
#                     },
#                     "srcImg": {
#                       "type": "Invocation",
#                       "arguments": {
#                         "image": {
#                           "type": "Invocation",
#                           "arguments": {
#                             "input": {
#                               "type": "Invocation",
#                               "arguments": {
#                                 "collection": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "collection": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "collection": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "collection": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "collection": {
#                                                   "type": "Invocation",
#                                                   "arguments": {
#                                                     "id": "LANDSAT/LC08/C01/T1_SR"
#                                                   },
#                                                   "functionName": "ImageCollection.load"
#                                                 },
#                                                 "key": "CLOUD_COVER"
#                                               },
#                                               "functionName": "Collection.limit"
#                                             },
#                                             "baseAlgorithm": {
#                                               "type": "Function",
#                                               "argumentNames": [
#                                                 "_MAPPING_VAR_0_0"
#                                               ],
#                                               "body": {
#                                                 "type": "Invocation",
#                                                 "arguments": {
#                                                   "destination": {
#                                                     "type": "Invocation",
#                                                     "arguments": {
#                                                       "input": {
#                                                         "type": "Invocation",
#                                                         "arguments": {
#                                                           "image": {
#                                                             "type": "ArgumentRef",
#                                                             "value": "_MAPPING_VAR_0_0"
#                                                           },
#                                                           "mask": {
#                                                             "type": "Invocation",
#                                                             "arguments": {
#                                                               "image1": {
#                                                                 "type": "Invocation",
#                                                                 "arguments": {
#                                                                   "image1": {
#                                                                     "type": "Invocation",
#                                                                     "arguments": {
#                                                                       "input": {
#                                                                         "type": "ArgumentRef",
#                                                                         "value": "_MAPPING_VAR_0_0"
#                                                                       },
#                                                                       "bandSelectors": [
#                                                                         "pixel_qa"
#                                                                       ]
#                                                                     },
#                                                                     "functionName": "Image.select"
#                                                                   },
#                                                                   "image2": {
#                                                                     "type": "Invocation",
#                                                                     "arguments": {
#                                                                       "value": 32
#                                                                     },
#                                                                     "functionName": "Image.constant"
#                                                                   }
#                                                                 },
#                                                                 "functionName": "Image.bitwiseAnd"
#                                                               },
#                                                               "image2": {
#                                                                 "type": "Invocation",
#                                                                 "arguments": {
#                                                                   "value": 0
#                                                                 },
#                                                                 "functionName": "Image.constant"
#                                                               }
#                                                             },
#                                                             "functionName": "Image.eq"
#                                                           }
#                                                         },
#                                                         "functionName": "Image.updateMask"
#                                                       },
#                                                       "bandSelectors": [
#                                                         "B[0-9]*"
#                                                       ]
#                                                     },
#                                                     "functionName": "Image.select"
#                                                   },
#                                                   "source": {
#                                                     "type": "ArgumentRef",
#                                                     "value": "_MAPPING_VAR_0_0"
#                                                   },
#                                                   "properties": [
#                                                     "system:time_start"
#                                                   ]
#                                                 },
#                                                 "functionName": "Image.copyProperties"
#                                               }
#                                             }
#                                           },
#                                           "functionName": "Collection.map"
#                                         },
#                                         "filter": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "rightField": "system:time_start",
#                                             "leftValue": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "start": "2015-01-01",
#                                                 "end": "2019-12-30"
#                                               },
#                                               "functionName": "DateRange"
#                                             }
#                                           },
#                                           "functionName": "Filter.dateRangeContains"
#                                         }
#                                       },
#                                       "functionName": "Collection.filter"
#                                     },
#                                     "filter": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "leftField": ".all",
#                                         "rightValue": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "geometry": {
#                                               "type": "Point",
#                                               "coordinates": [
#                                                 -70.0522,
#                                                 18.749
#                                               ]
#                                             }
#                                           },
#                                           "functionName": "Feature"
#                                         }
#                                       },
#                                       "functionName": "Filter.intersects"
#                                     }
#                                   },
#                                   "functionName": "Collection.filter"
#                                 }
#                               },
#                               "functionName": "Collection.first"
#                             },
#                             "bandSelectors": [
#                               "B[2-5]"
#                             ]
#                           },
#                           "functionName": "Image.select"
#                         },
#                         "reducer": {
#                           "type": "Invocation",
#                           "arguments": {},
#                           "functionName": "Reducer.mean"
#                         },
#                         "kernel": {
#                           "type": "Invocation",
#                           "arguments": {
#                             "radius": 1,
#                             "units": "pixels"
#                           },
#                           "functionName": "Kernel.square"
#                         }
#                       },
#                       "functionName": "Image.reduceNeighborhood"
#                     }
#                   },
#                   "functionName": "Image.addBands"
#                 },
#                 "collection": {
#                   "type": "Invocation",
#                   "arguments": {
#                     "collection": {
#                       "type": "Invocation",
#                       "arguments": {
#                         "tableId": "ft:1jHRNbgg-nvJ-TNJBjeB28apGsIvdrySp3WbL_PZG"
#                       },
#                       "functionName": "Collection.loadTable"
#                     },
#                     "lookupIn": [
#                       1,
#                       2,
#                       3,
#                       4
#                     ],
#                     "lookupOut": [
#                       0,
#                       1,
#                       2,
#                       3
#                     ],
#                     "columnName": "name"
#                   },
#                   "functionName": "Collection.remap"
#                 },
#                 "properties": [
#                   "name"
#                 ],
#                 "scale": 30
#               },
#               "functionName": "Image.sampleRegions"
#             },
#             "classProperty": [
#               "name"
#             ]
#           },
#           "functionName": "Classifier.train"
#         }
#       },
#       "functionName": "Classifier.confusionMatrix"
#     }
#   },
#   "functionName": "ConfusionMatrix"
# })
# Training overall accuracy:  ee.Number({
#   "type": "Invocation",
#   "arguments": {
#     "confusionMatrix": {
#       "type": "Invocation",
#       "arguments": {
#         "array": {
#           "type": "Invocation",
#           "arguments": {
#             "classifier": {
#               "type": "Invocation",
#               "arguments": {
#                 "classifier": {
#                   "type": "Invocation",
#                   "arguments": {
#                     "numberOfTrees": 10
#                   },
#                   "functionName": "Classifier.randomForest"
#                 },
#                 "features": {
#                   "type": "Invocation",
#                   "arguments": {
#                     "image": {
#                       "type": "Invocation",
#                       "arguments": {
#                         "dstImg": {
#                           "type": "Invocation",
#                           "arguments": {
#                             "dstImg": {
#                               "type": "Invocation",
#                               "arguments": {
#                                 "input": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "collection": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "collection": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "collection": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "collection": {
#                                                   "type": "Invocation",
#                                                   "arguments": {
#                                                     "collection": {
#                                                       "type": "Invocation",
#                                                       "arguments": {
#                                                         "id": "LANDSAT/LC08/C01/T1_SR"
#                                                       },
#                                                       "functionName": "ImageCollection.load"
#                                                     },
#                                                     "key": "CLOUD_COVER"
#                                                   },
#                                                   "functionName": "Collection.limit"
#                                                 },
#                                                 "baseAlgorithm": {
#                                                   "type": "Function",
#                                                   "argumentNames": [
#                                                     "_MAPPING_VAR_0_0"
#                                                   ],
#                                                   "body": {
#                                                     "type": "Invocation",
#                                                     "arguments": {
#                                                       "destination": {
#                                                         "type": "Invocation",
#                                                         "arguments": {
#                                                           "input": {
#                                                             "type": "Invocation",
#                                                             "arguments": {
#                                                               "image": {
#                                                                 "type": "ArgumentRef",
#                                                                 "value": "_MAPPING_VAR_0_0"
#                                                               },
#                                                               "mask": {
#                                                                 "type": "Invocation",
#                                                                 "arguments": {
#                                                                   "image1": {
#                                                                     "type": "Invocation",
#                                                                     "arguments": {
#                                                                       "image1": {
#                                                                         "type": "Invocation",
#                                                                         "arguments": {
#                                                                           "input": {
#                                                                             "type": "ArgumentRef",
#                                                                             "value": "_MAPPING_VAR_0_0"
#                                                                           },
#                                                                           "bandSelectors": [
#                                                                             "pixel_qa"
#                                                                           ]
#                                                                         },
#                                                                         "functionName": "Image.select"
#                                                                       },
#                                                                       "image2": {
#                                                                         "type": "Invocation",
#                                                                         "arguments": {
#                                                                           "value": 32
#                                                                         },
#                                                                         "functionName": "Image.constant"
#                                                                       }
#                                                                     },
#                                                                     "functionName": "Image.bitwiseAnd"
#                                                                   },
#                                                                   "image2": {
#                                                                     "type": "Invocation",
#                                                                     "arguments": {
#                                                                       "value": 0
#                                                                     },
#                                                                     "functionName": "Image.constant"
#                                                                   }
#                                                                 },
#                                                                 "functionName": "Image.eq"
#                                                               }
#                                                             },
#                                                             "functionName": "Image.updateMask"
#                                                           },
#                                                           "bandSelectors": [
#                                                             "B[0-9]*"
#                                                           ]
#                                                         },
#                                                         "functionName": "Image.select"
#                                                       },
#                                                       "source": {
#                                                         "type": "ArgumentRef",
#                                                         "value": "_MAPPING_VAR_0_0"
#                                                       },
#                                                       "properties": [
#                                                         "system:time_start"
#                                                       ]
#                                                     },
#                                                     "functionName": "Image.copyProperties"
#                                                   }
#                                                 }
#                                               },
#                                               "functionName": "Collection.map"
#                                             },
#                                             "filter": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "rightField": "system:time_start",
#                                                 "leftValue": {
#                                                   "type": "Invocation",
#                                                   "arguments": {
#                                                     "start": "2015-01-01",
#                                                     "end": "2019-12-30"
#                                                   },
#                                                   "functionName": "DateRange"
#                                                 }
#                                               },
#                                               "functionName": "Filter.dateRangeContains"
#                                             }
#                                           },
#                                           "functionName": "Collection.filter"
#                                         },
#                                         "filter": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "leftField": ".all",
#                                             "rightValue": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "geometry": {
#                                                   "type": "Point",
#                                                   "coordinates": [
#                                                     -70.0522,
#                                                     18.749
#                                                   ]
#                                                 }
#                                               },
#                                               "functionName": "Feature"
#                                             }
#                                           },
#                                           "functionName": "Filter.intersects"
#                                         }
#                                       },
#                                       "functionName": "Collection.filter"
#                                     }
#                                   },
#                                   "functionName": "Collection.first"
#                                 },
#                                 "bandSelectors": [
#                                   "B[2-5]"
#                                 ]
#                               },
#                               "functionName": "Image.select"
#                             },
#                             "srcImg": {
#                               "type": "Invocation",
#                               "arguments": {
#                                 "input": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "input": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "collection": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "collection": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "collection": {
#                                                   "type": "Invocation",
#                                                   "arguments": {
#                                                     "collection": {
#                                                       "type": "Invocation",
#                                                       "arguments": {
#                                                         "collection": {
#                                                           "type": "Invocation",
#                                                           "arguments": {
#                                                             "id": "LANDSAT/LC08/C01/T1_SR"
#                                                           },
#                                                           "functionName": "ImageCollection.load"
#                                                         },
#                                                         "key": "CLOUD_COVER"
#                                                       },
# ...
#                                                       "functionName": "DateRange"
#                                                     }
#                                                   },
#                                                   "functionName": "Filter.dateRangeContains"
#                                                 }
#                                               },
#                                               "functionName": "Collection.filter"
#                                             },
#                                             "filter": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "leftField": ".all",
#                                                 "rightValue": {
#                                                   "type": "Invocation",
#                                                   "arguments": {
#                                                     "geometry": {
#                                                       "type": "Point",
#                                                       "coordinates": [
#                                                         -70.0522,
#                                                         18.749
#                                                       ]
#                                                     }
#                                                   },
#                                                   "functionName": "Feature"
#                                                 }
#                                               },
#                                               "functionName": "Filter.intersects"
#                                             }
#                                           },
#                                           "functionName": "Collection.filter"
#                                         }
#                                       },
#                                       "functionName": "Collection.first"
#                                     },
#                                     "bandSelectors": [
#                                       "B[2-5]"
#                                     ]
#                                   },
#                                   "functionName": "Image.select"
#                                 },
#                                 "bandNames": [
#                                   "B5",
#                                   "B4"
#                                 ]
#                               },
#                               "functionName": "Image.normalizedDifference"
#                             }
#                           },
#                           "functionName": "Image.addBands"
#                         },
#                         "srcImg": {
#                           "type": "Invocation",
#                           "arguments": {
#                             "image": {
#                               "type": "Invocation",
#                               "arguments": {
#                                 "input": {
#                                   "type": "Invocation",
#                                   "arguments": {
#                                     "collection": {
#                                       "type": "Invocation",
#                                       "arguments": {
#                                         "collection": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "collection": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "collection": {
#                                                   "type": "Invocation",
#                                                   "arguments": {
#                                                     "collection": {
#                                                       "type": "Invocation",
#                                                       "arguments": {
#                                                         "id": "LANDSAT/LC08/C01/T1_SR"
#                                                       },
#                                                       "functionName": "ImageCollection.load"
#                                                     },
#                                                     "key": "CLOUD_COVER"
#                                                   },
#                                                   "functionName": "Collection.limit"
#                                                 },
#                                                 "baseAlgorithm": {
#                                                   "type": "Function",
#                                                   "argumentNames": [
#                                                     "_MAPPING_VAR_0_0"
#                                                   ],
#                                                   "body": {
#                                                     "type": "Invocation",
#                                                     "arguments": {
#                                                       "destination": {
#                                                         "type": "Invocation",
#                                                         "arguments": {
#                                                           "input": {
#                                                             "type": "Invocation",
#                                                             "arguments": {
#                                                               "image": {
#                                                                 "type": "ArgumentRef",
#                                                                 "value": "_MAPPING_VAR_0_0"
#                                                               },
#                                                               "mask": {
#                                                                 "type": "Invocation",
#                                                                 "arguments": {
#                                                                   "image1": {
#                                                                     "type": "Invocation",
#                                                                     "arguments": {
#                                                                       "image1": {
#                                                                         "type": "Invocation",
#                                                                         "arguments": {
#                                                                           "input": {
#                                                                             "type": "ArgumentRef",
#                                                                             "value": "_MAPPING_VAR_0_0"
#                                                                           },
#                                                                           "bandSelectors": [
#                                                                             "pixel_qa"
#                                                                           ]
#                                                                         },
#                                                                         "functionName": "Image.select"
#                                                                       },
#                                                                       "image2": {
#                                                                         "type": "Invocation",
#                                                                         "arguments": {
#                                                                           "value": 32
#                                                                         },
#                                                                         "functionName": "Image.constant"
#                                                                       }
#                                                                     },
#                                                                     "functionName": "Image.bitwiseAnd"
#                                                                   },
#                                                                   "image2": {
#                                                                     "type": "Invocation",
#                                                                     "arguments": {
#                                                                       "value": 0
#                                                                     },
#                                                                     "functionName": "Image.constant"
#                                                                   }
#                                                                 },
#                                                                 "functionName": "Image.eq"
#                                                               }
#                                                             },
#                                                             "functionName": "Image.updateMask"
#                                                           },
#                                                           "bandSelectors": [
#                                                             "B[0-9]*"
#                                                           ]
#                                                         },
#                                                         "functionName": "Image.select"
#                                                       },
#                                                       "source": {
#                                                         "type": "ArgumentRef",
#                                                         "value": "_MAPPING_VAR_0_0"
#                                                       },
#                                                       "properties": [
#                                                         "system:time_start"
#                                                       ]
#                                                     },
#                                                     "functionName": "Image.copyProperties"
#                                                   }
#                                                 }
#                                               },
#                                               "functionName": "Collection.map"
#                                             },
#                                             "filter": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "rightField": "system:time_start",
#                                                 "leftValue": {
#                                                   "type": "Invocation",
#                                                   "arguments": {
#                                                     "start": "2015-01-01",
#                                                     "end": "2019-12-30"
#                                                   },
#                                                   "functionName": "DateRange"
#                                                 }
#                                               },
#                                               "functionName": "Filter.dateRangeContains"
#                                             }
#                                           },
#                                           "functionName": "Collection.filter"
#                                         },
#                                         "filter": {
#                                           "type": "Invocation",
#                                           "arguments": {
#                                             "leftField": ".all",
#                                             "rightValue": {
#                                               "type": "Invocation",
#                                               "arguments": {
#                                                 "geometry": {
#                                                   "type": "Point",
#                                                   "coordinates": [
#                                                     -70.0522,
#                                                     18.749
#                                                   ]
#                                                 }
#                                               },
#                                               "functionName": "Feature"
#                                             }
#                                           },
#                                           "functionName": "Filter.intersects"
#                                         }
#                                       },
#                                       "functionName": "Collection.filter"
#                                     }
#                                   },
#                                   "functionName": "Collection.first"
#                                 },
#                                 "bandSelectors": [
#                                   "B[2-5]"
#                                 ]
#                               },
#                               "functionName": "Image.select"
#                             },
#                             "reducer": {
#                               "type": "Invocation",
#                               "arguments": {},
#                               "functionName": "Reducer.mean"
#                             },
#                             "kernel": {
#                               "type": "Invocation",
#                               "arguments": {
#                                 "radius": 1,
#                                 "units": "pixels"
#                               },
#                               "functionName": "Kernel.square"
#                             }
#                           },
#                           "functionName": "Image.reduceNeighborhood"
#                         }
#                       },
#                       "functionName": "Image.addBands"
#                     },
#                     "collection": {
#                       "type": "Invocation",
#                       "arguments": {
#                         "collection": {
#                           "type": "Invocation",
#                           "arguments": {
#                             "tableId": "ft:1jHRNbgg-nvJ-TNJBjeB28apGsIvdrySp3WbL_PZG"
#                           },
#                           "functionName": "Collection.loadTable"
#                         },
#                         "lookupIn": [
#                           1,
#                           2,
#                           3,
#                           4
#                         ],
#                         "lookupOut": [
#                           0,
#                           1,
#                           2,
#                           3
#                         ],
#                         "columnName": "name"
#                       },
#                       "functionName": "Collection.remap"
#                     },
#                     "properties": [
#                       "name"
#                     ],
#                     "scale": 30
#                   },
#                   "functionName": "Image.sampleRegions"
#                 },
#                 "classProperty": [
#                   "name"
#                 ]
#               },
#               "functionName": "Classifier.train"
#             }
#           },
#           "functionName": "Classifier.confusionMatrix"
#         }
#       },
#       "functionName": "ConfusionMatrix"
#     }
#   },
#   "functionName": "ConfusionMatrix.accuracy"
# })

# %%
validation = result.sample(240)

# %%
trainingTesting = training.randomColumn()
trainingSet = trainingTesting.filter(ee.Filter.lessThan('random', 0.6)) 
testingSet = trainingTesting.filter(ee.Filter.greaterThanOrEquals('random', 0.6))
